# %% [markdown]
# ### Installing PyDrive

# %%
# !pip install -U -q PyDrive
# !pip install pydrive --upgrade
# Out:
# Requirement already up-to-date: pydrive in /usr/local/lib/python3.6/dist-packages (1.3.1)
# Requirement already satisfied, skipping upgrade: PyYAML>=3.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (3.13)
# Requirement already satisfied, skipping upgrade: oauth2client>=4.0.0 in /usr/local/lib/python3.6/dist-packages (from pydrive) (4.1.3)
# Requirement already satisfied, skipping upgrade: google-api-python-client>=1.2 in /usr/local/lib/python3.6/dist-packages (from pydrive) (1.7.11)
# Requirement already satisfied, skipping upgrade: pyasn1>=0.1.7 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.4.8)
# Requirement already satisfied, skipping upgrade: six>=1.6.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (1.12.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.2.8)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (4.0)
# Requirement already satisfied, skipping upgrade: httplib2>=0.9.1 in /usr/local/lib/python3.6/dist-packages (from oauth2client>=4.0.0->pydrive) (0.11.3)
# Requirement already satisfied, skipping upgrade: uritemplate<4dev,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (3.0.1)
# Requirement already satisfied, skipping upgrade: google-auth>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (1.7.2)
# Requirement already satisfied, skipping upgrade: google-auth-httplib2>=0.0.3 in /usr/local/lib/python3.6/dist-packages (from google-api-python-client>=1.2->pydrive) (0.0.3)
# Requirement already satisfied, skipping upgrade: setuptools>=40.3.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (45.1.0)
# Requirement already satisfied, skipping upgrade: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth>=1.4.1->google-api-python-client>=1.2->pydrive) (3.1.1)

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


# After a specific amount of time Pydrive logs out, the enxt function checks for that and if it has happend trys log in again
# you will not to log in to your account just the first time, the next times it will be automatic, we will use this function later on.
def authorizeIfLoggedOut():
  try:
    file_list_GDrive = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()

  except:    
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

# %% [markdown]
# ## Importing modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)


# After a specific amount of time Pydrive logs out, the enxt function checks for that and if it has happend trys log in again
# you will not to log in to your account just the first time, the next times it will be automatic, we will use this function later on.
def authorizeIfLoggedOut():
  try:
    file_list_GDrive = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()

  except:    
    auth.authenticate_user()
    gauth = GoogleAuth()
    gauth.credentials = GoogleCredentials.get_application_default()
    drive = GoogleDrive(gauth)

# %%
# this will just check if we are logged out it logs in
authorizeIfLoggedOut()

file_list_GDrive = drive.ListFile({'q': "'root' in parents and trashed=false"}).GetList()

for file1 in file_list_GDrive:  
    if "Behzad_Project" in file1['title']:
        Folder_ID_Behzad_Project= file1['id']

print(Folder_ID_Behzad_Project)

file_list_Behzad_Project = drive.ListFile({'q': "'%s' in parents and trashed=false" % Folder_ID_Behzad_Project}).GetList()

for file2 in file_list_Behzad_Project:  
    if "Data" in file2['title']:
        Folder_ID_Data= file2['id']
        
for file4 in file_list_Behzad_Project:
  
    if "Figures" in file4['title']:
        Folder_ID_Figures= file4['id']        
        
        
file_list_Data = drive.ListFile({'q': "'%s' in parents and trashed=false" % Folder_ID_Data}).GetList()

for file3 in file_list_Data:  
    if "electricity.csv" in file3['title']:
        print ("electricity.csv exists")
        ID_electricity= file3['id']
        file_electricity = drive.CreateFile({'id': ID_electricity})
        file_electricity.GetContentFile('electricity.csv') 

for file5 in file_list_Data:  
  if "LBNL_extra.csv" in file5['title']:
    print ("LBNL_extra.csv exists")
    ID_LBNL_extra= file5['id']
    file_LBNL_extra = drive.CreateFile({'id': ID_LBNL_extra})
    file_LBNL_extra.GetContentFile('LBNL1_extra.csv')
# Out:
# 1AA6Z3AwUf-wNk7z1YuVfouA9CfhRe1wg
# electricity.csv exists
# LBNL_extra.csv exists

# %% [markdown]
# # Functions

# %%
def gdrive_authorize():
  authorizeIfLoggedOut()
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

# %%
def LoadFile(fileName):
  for file in file_list_Data:  
    if fileName in file['title']:
        print (fileName+ " exists")
        ID_fileName= file['id']
        file_fileName = drive.CreateFile({'id': ID_fileName})
        file_fileName.GetContentFile(fileName)

# %%
def CSV2DF(fileName):
  authorizeIfLoggedOut()
  auth.authenticate_user()
  gauth = GoogleAuth()
  gauth.credentials = GoogleCredentials.get_application_default()
  drive = GoogleDrive(gauth)

  for file in file_list_Data:  
    if fileName in file['title']:
        print (fileName+ " exists")
        ID_fileName= file['id']
        file_fileName = drive.CreateFile({'id': ID_fileName})
        file_fileName.GetContentFile(fileName) 
  DF_output = pd.read_csv(fileName, sep =",", index_col = 0)
  oldIndex_DF_output = DF_output.index
  newIndex_DF_output = pd.to_datetime(oldIndex_DF_output)
  DF_output.index = newIndex_DF_output
  return(DF_output)

# %%
def DFWriter(df,file_name):
  Files_folder ="drive/My Drive/Behzad_Project"
  path = os.path.join(Files_folder,file_name)
  
  df.to_csv(path, encoding='utf-8')

# %%
def WeekendDetector(day):
    if (day == 5 or day==6):
        weekendLabel = 1
    else:
        weekendLabel = 0
    return weekendLabel

# %%
def workingHourDetector(hour):
    if (hour>=9 and hour <= 17):
        workingHourLabel = 1
    else:
        workingHourLabel = 0
    return workingHourLabel

# %%
def lag_gen_feature(inputDF,columnName,lag_start,lag_end,lag_interval):
    for i in range(lag_start,lag_end+1, lag_interval):
        new_column_name = columnName+" -"+str(i)+"h"
        if new_column_name in inputDF.columns:
            pass
        else:
            print (new_column_name)
            inputDF.loc[:,new_column_name] = inputDF.loc[:,columnName].shift(i)
            inputDF.dropna(inplace=True)
    return inputDF

# %%
def remove_feature(inputDF,feature):
  if feature in inputDF.columns:
    inputDF.drop(feature, axis=1, inplace=True)
    inputDF.dropna(inplace=True)
    print (feature + " was removed succesfully from the dataframe")
    return inputDF

# %%
def remove_anomaly(inputDF,index,remove_target):
  if np.size(index)==0:
    pass
  else:
    for i in index:
      inputDF.loc[index,remove_target] = None
      inputDF.dropna(inplace=True)

#we can also use the concat method used in the code

# %% [markdown]
# # Importing datasets

# %% [markdown]
# ## Electricity Consumption

# %% [markdown]
# ### Importing and formatting the consumption Dataset

# %%
# Comment by Arian: As we want to export file in the google drive we have to mount it first by the following command
# Attentin: When calling a directory you should drop "/content" at the begining of the path; as I defined in the saving path in DFWriter functoin.
from google.colab import drive
drive.mount('/content/drive')

# Add the local_modules directory to the set of paths
# Python uses to look for imports.
import sys
sys.path.append('local_modules')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# ### Using the CSV2DF function
#
# to import datasets as dataframes and convert the index to date-time format simultaneously and neatly!
#
# Attention ! : I don't know why but while using google colab, you have to run the "authorizeIfLoggedOut" part again otherwise the function "CSV2DF" ends up with the error of not recognizing Google's "CreateFile" function!

# %%
DF_main =CSV2DF("electricity.csv")
# Out:
# electricity.csv exists

# %%
DF_main_clean = DF_main.dropna() 
DFWriter(DF_main_clean,"DF_main_clean.csv")
DF_main_clean
# Out:
#                      consumption
# Timestamp
# 2014-01-01 00:30:00     22.81250
# 2014-01-01 00:45:00     24.66500
# 2014-01-01 01:00:00     24.17250
# 2014-01-01 01:15:00     24.95000
# 2014-01-01 01:30:00     23.61750
# ...                          ...
# 2015-06-30 22:45:00     35.97594
# 2015-06-30 23:00:00     29.00007
# 2015-06-30 23:15:00     31.00000
# 2015-06-30 23:30:00     30.01600
# 2015-06-30 23:45:00     31.97600
#
# [46111 rows x 1 columns]

# %% [markdown]
# So in this way we completely remove the rows in which there is one NaN
# If you wanted to apply dropna on DF_main itself you have two options
# DF_main = DF_main.dropna()
# DF_main.dropna(inplace=True)

# %% [markdown]
# ### Importing and formatting extra data from Data Loggers of LBNL74

# %%
#LoadFile("LBNL1_2014.csv")
#LoadFile("LBNL1_2015.csv")
#LoadFile("LBNL_extra_clean.csv")

# %%
DF_extra_clean=CSV2DF("LBNL_extra_clean.csv")
DF_extra_clean.tail(30)
# Out:
# LBNL_extra_clean.csv exists
#                      temp_set_1  temp_set_2     RH  wind_speed  precep     rad
# Date Time
# 2015-06-30 16:30:00       77.56       76.57  37.27        5.53     0.0  626.40
# 2015-06-30 21:15:00     35.00000
# 2015-06-30 21:30:00     33.97600
# 2015-06-30 21:45:00     33.01600
# 2015-06-30 22:00:00     35.01596
# 2015-06-30 22:15:00     30.95992
# 2015-06-30 22:30:00     32.04000
# 2015-06-30 22:45:00     35.97594
# 2015-06-30 23:00:00     29.00007
# 2015-06-30 23:15:00     31.00000
# 2015-06-30 23:30:00     30.01600
# 2015-06-30 23:45:00     31.97600

# %% [markdown]
# Now We merge the two dataframes

# %%
DF_extra_clean.drop_duplicates(inplace=True)
DF_main_clean.drop_duplicates(inplace=True)
#result = DF_main_clean.merge(DF_extra_clean)
DF_joined=pd.merge( DF_main_clean, DF_extra_clean, left_index=True, right_index=True)
DF_joined
# Out:
#                      consumption  temp_set_1  ...  precep     rad
# 2014-01-01 22:00:00     24.97000       57.34  ...     0.0    0.00
# 2014-01-01 22:15:00     22.94750       56.44  ...     0.0    0.00
# 2014-01-01 22:30:00     23.41250       56.23  ...     0.0    0.00
# 2014-01-01 22:45:00     24.51250       56.26  ...     0.0    0.00
# 2014-01-01 23:00:00     23.82000       57.24  ...     0.0    0.00
# ...                          ...         ...  ...     ...     ...
# 2015-06-30 19:30:00     51.99200       82.90  ...     0.0  191.10
# 2015-06-30 19:45:00     51.95200       79.59  ...     0.0  144.20
# 2015-06-30 20:00:00     47.01600       73.71  ...     0.0   96.00
# 2015-06-30 22:15:00     30.95992       65.16  ...     0.0    0.17
# 2015-06-30 22:45:00     35.97594       67.84  ...     0.0    0.03
#
# [34325 rows x 7 columns]

# %% [markdown]
# ##Gas Consumption

# %% [markdown]
# ###Importing and formatting the consumption Datasets

# %% [markdown]
# ###using the CSV2DF function

# %%
DF_main_Gas =CSV2DF("Gas.csv")
# Out:
# Gas.csv exists

# %%
DF_main_clean_Gas = DF_main_Gas.dropna() 
DFWriter(DF_main_clean_Gas,"DF_main_Gas_clean.csv")
DF_main_clean_Gas.index
#DF_main_Gas.dropna(inplace=True)
#DF_main_clean_Gas.rename(index={'Timestamp': 'Date Time'})
# Out:
# DatetimeIndex(['2014-01-01 00:00:00', '2014-01-01 00:05:00',
#                '2014-01-01 00:10:00', '2014-01-01 00:15:00',
#                '2014-01-01 00:20:00', '2014-01-01 00:25:00',
#                '2014-01-01 00:30:00', '2014-01-01 00:35:00',
#                '2014-01-01 00:40:00', '2014-01-01 00:45:00',
#                ...
#                '2015-06-29 16:05:00', '2015-06-29 16:10:00',
#                '2015-06-29 16:15:00', '2015-06-29 16:20:00',
#                '2015-06-29 16:25:00', '2015-06-29 16:30:00',
#                '2015-06-29 16:35:00', '2015-06-29 16:40:00',
#                '2015-06-29 16:45:00', '2015-06-29 16:50:00'],
#               dtype='datetime64[ns]', name='Date Time', length=156592, freq=None)

# %% [markdown]
# ###Importing and formatting extra data from Data loggers of LBNL74

# %%
DF_extra_clean_Gas=CSV2DF("LBNL_extra_clean.csv")
DF_extra_clean_Gas.tail(30)
DF_extra_clean_Gas.index
# Out:
# LBNL_extra_clean.csv exists
# DatetimeIndex(['2014-01-01 22:00:00', '2014-01-01 22:15:00',
#                '2014-01-01 22:30:00', '2014-01-01 22:45:00',
#                '2014-01-01 23:00:00', '2014-01-01 23:15:00',
#                '2014-01-01 23:30:00', '2014-01-01 23:45:00',
#                '2014-01-02 00:00:00', '2014-01-02 00:15:00',
#                ...
#                '2015-06-30 21:30:00', '2015-06-30 21:45:00',
#                '2015-06-30 22:00:00', '2015-06-30 22:15:00',
#                '2015-06-30 22:30:00', '2015-06-30 22:45:00',
#                '2015-06-30 23:00:00', '2015-06-30 23:15:00',
#                '2015-06-30 23:30:00', '2015-06-30 23:45:00'],
#               dtype='datetime64[ns]', name='Date Time', length=52324, freq=None)

# %%
#DF_extra_clean_Gas.drop_duplicates(inplace=True)
#DF_main_clean_Gas.drop_duplicates(inplace=True)
#DF_joined_Gas=pd.concat([DF_main_clean_Gas, DF_extra_clean_Gas, DF_extra_clean_Gas],sort=False)
DF_joined_Gas=pd.merge(DF_main_clean_Gas, DF_extra_clean_Gas, left_index=True, right_index=True)
#DF_joined_Gas.dropna(inplace=True)
#DF_joined_Gas=DF_joined_Gas.sort_index
DF_joined_Gas.head(200)
#DF_extra_clean_Gas.head(100)
#DF_main_clean_Gas
#DF_extra_clean_Gas
# Out:
#                      Consumption  temp_set_1  ...  precep  rad
# Date Time                                     ...
# 2014-01-01 22:00:00     7.759263       57.34  ...     0.0  0.0
# 2014-01-01 22:15:00     8.923182       56.44  ...     0.0  0.0
# 2014-01-01 22:30:00    10.281476       56.23  ...     0.0  0.0
# 2014-01-01 22:45:00    10.475268       56.26  ...     0.0  0.0
# 2014-01-01 23:00:00     9.893309       57.24  ...     0.0  0.0
# ...                          ...         ...  ...     ...  ...
# 2014-01-03 22:45:00     6.789719       56.52  ...     0.0  0.0
# 2014-01-03 23:00:00     7.759263       57.25  ...     0.0  0.0
# 2014-01-03 23:15:00     8.147430       56.43  ...     0.0  0.0
# 2014-01-03 23:30:00     7.371678       54.32  ...     0.0  0.0
# 2014-01-03 23:45:00     8.923182       52.72  ...     0.0  0.0
#
# [200 rows x 7 columns]

# %% [markdown]
# # Adding time-related Features
#
# The first thing I would do its to extract the hour and assign it to a column called hour !

# %% [markdown]
# ### For Electricity Consumption

# %%
DF_joined.loc[:,"hour"]=DF_joined.index.hour
DF_joined.head(30)
# Out:
#                      consumption  temp_set_1  temp_set_2  ...  precep  rad  hour
# 2014-01-01 22:00:00      24.9700       57.34       57.87  ...     0.0  0.0    22
# 2014-01-01 22:15:00      22.9475       56.44       57.69  ...     0.0  0.0    22
# 2014-01-01 22:30:00      23.4125       56.23       57.36  ...     0.0  0.0    22
# 2014-01-01 22:45:00      24.5125       56.26       58.14  ...     0.0  0.0    22
# 2014-01-01 23:00:00      23.8200       57.24       58.50  ...     0.0  0.0    23
# 2014-01-01 23:15:00      25.6825       57.43       58.66  ...     0.0  0.0    23
# 2014-01-01 23:30:00      23.0175       58.08       59.29  ...     0.0  0.0    23
# 2014-01-01 23:45:00      24.4200       58.42       58.80  ...     0.0  0.0    23
# 2014-01-02 00:00:00      23.2550       56.44       56.71  ...     0.0  0.0     0
# 2014-01-02 01:45:00      21.6400       57.97  ...   0.258819   0.965926
# 2014-01-02 02:00:00      24.2075       57.97  ...   0.500000   0.866025
# 2014-01-02 02:15:00      21.9825       57.70  ...   0.500000   0.866025
# 2014-01-02 02:30:00      25.0175       57.20  ...   0.500000   0.866025
# 2014-01-02 03:00:00      23.2375       56.86  ...   0.707107   0.707107
# 2014-01-02 03:15:00      23.1750       58.23  ...   0.707107   0.707107
# 2014-01-02 03:30:00      24.1625       58.17  ...   0.707107   0.707107
# 2014-01-02 03:45:00      24.8800       56.88  ...   0.707107   0.707107
# 2014-01-02 04:00:00      25.7725       55.85  ...   0.866025   0.500000
# 2014-01-02 04:15:00      22.4300       56.48  ...   0.866025   0.500000
# 2014-01-02 04:30:00      22.1250       56.41  ...   0.866025   0.500000
# 2014-01-02 04:45:00      24.2825       56.25  ...   0.866025   0.500000
# 2014-01-02 05:00:00      23.7775       55.38  ...   0.965926   0.258819
# 2014-01-02 05:15:00      24.0350       53.82  ...   0.965926   0.258819
# 2014-01-02 05:30:00      21.9400       52.61  ...   0.965926   0.258819
# 2014-01-02 05:45:00      26.4300       54.12  ...   0.965926   0.258819
#
# [30 rows x 10 columns]

# %% [markdown]
# Now let's do the same thing for other parameters (day of week, month, week of year

# %%
DF_joined.loc[:,"month"] = DF_joined.index.month
DF_joined.loc[:,"dayOfWeek"]=DF_joined.index.dayofweek
DF_joined.loc[:,"weekOfYear"] = DF_joined.index.week
DF_joined.tail(52)
# Out:
#                      consumption  temp_set_1  ...  dayOfWeek  weekOfYear
# 2015-06-28 09:30:00     35.03997       57.07  ...          6          26
# 2015-06-29 01:15:00     24.06400       54.55  ...          0          27
# 2015-06-29 08:30:00     31.02396       54.82  ...          0          27
# 2015-06-29 09:15:00     78.98400       56.86  ...          0          27
# 2015-06-29 09:45:00     68.74662       58.06  ...          0          27
# 2015-06-29 10:15:00     61.71682       60.19  ...          0          27
# 2015-06-29 10:45:00     39.03999       61.20  ...          0          27
# 2015-06-29 11:30:00     40.99204       63.72  ...          0          27
# 2015-06-29 13:00:00     46.01601       66.90  ...          0          27
# 2015-06-29 13:45:00     47.99200       68.95  ...          0          27
# 2015-06-29 15:30:00     49.99200       70.65  ...          0          27
# 2015-06-29 15:45:00     49.96800       70.39  ...          0          27
# 2015-06-29 16:15:00     51.03200       70.81  ...          0          27
# 2015-06-29 16:45:00     52.01600       71.08  ...          0          27
# 2015-06-29 17:00:00     50.03200       72.70  ...          0          27
# 2015-06-29 17:30:00     50.01600       72.70  ...          0          27
# 2015-06-29 17:45:00     45.99200       72.82  ...          0          27
# 2015-06-29 18:30:00     40.99199       74.35  ...          0          27
# 2015-06-29 22:30:00     28.06395       60.53  ...          0          27
# 2015-06-30 07:30:00     27.02395       58.66  ...          1          27
# 2015-06-30 09:15:00     39.47200       64.29  ...          1          27
# 2015-06-30 09:30:00     42.49200       65.77  ...          1          27
# 2015-06-30 10:15:00     50.99200       67.50  ...          1          27
# 2015-06-30 10:30:00     49.03200       68.88  ...          1          27
# 2015-06-30 11:15:00     53.03199       72.05  ...          1          27
# 2015-06-30 11:30:00     51.98400       72.01  ...          1          27
# 2015-06-30 11:45:00     57.03200       72.19  ...          1          27
# 2015-06-30 12:15:00     53.94400       73.56  ...          1          27
# 2015-06-30 12:45:00     58.00800       75.63  ...          1          27
# 2015-06-30 13:45:00     63.98400       78.78  ...          1          27
# 2015-06-30 14:00:00     64.00800       78.75  ...          1          27
# 2015-06-30 14:15:00     64.02400       79.90  ...          1          27
# 2015-06-30 14:30:00     67.98398       81.10  ...          1          27
# 2015-06-30 14:45:00     62.00794       80.71  ...          1          27
# 2015-06-30 15:00:00     64.98400       79.59  ...          1          27
# 2015-06-30 15:15:00     71.04797       78.96  ...          1          27
# 2015-06-30 15:30:00     62.96800       78.67  ...          1          27
# 2015-06-30 15:45:00     62.98400       78.10  ...          1          27
# 2015-06-30 16:00:00     68.00790       78.06  ...          1          27
# 2015-06-30 16:15:00     57.00798       77.92  ...          1          27
# 2015-06-30 16:30:00     63.03200       77.56  ...          1          27
# 2015-06-30 16:45:00     54.94390       75.76  ...          1          27
# 2015-06-30 17:00:00     44.99202       74.28  ...          1          27
# 2015-06-30 17:30:00     50.03201       73.98  ...          1          27
# 2015-06-30 17:45:00     42.96788       76.30  ...          1          27
# 2015-06-30 18:15:00     53.00767       75.15  ...          1          27
# 2015-06-30 18:30:00     37.97601       75.04  ...          1          27
# 2015-06-30 19:30:00     51.99200       82.90  ...          1          27
# 2015-06-30 19:45:00     51.95200       79.59  ...          1          27
# 2015-06-30 20:00:00     47.01600       73.71  ...          1          27
# 2015-06-30 22:15:00     30.95992       65.16  ...          1          27
# 2015-06-30 22:45:00     35.97594       67.84  ...          1          27
#
# [52 rows x 13 columns]

# %% [markdown]
# We can now apply these functions on the corresponding colums

# %%
DF_joined.loc[:,"weekendLabel"] = DF_joined.loc[:,"dayOfWeek"].apply(WeekendDetector)
DF_joined.loc[:,"WorkingHourLabel"] = DF_joined.loc[:,"hour"].apply(workingHourDetector)
DF_joined.loc[:,"temp_avg"] = 0.5*(DF_joined.loc[:,"temp_set_1"]+DF_joined.loc[:,"temp_set_2"])

# %%
DF_joined
# Out:
#                      consumption  temp_set_1  ...  WorkingHourLabel  temp_avg
# 2014-01-01 22:00:00     24.97000       57.34  ...                 0    57.605
# 2014-01-01 22:15:00     22.94750       56.44  ...                 0    57.065
# 2014-01-01 22:30:00     23.41250       56.23  ...                 0    56.795
# 2014-01-01 22:45:00     24.51250       56.26  ...                 0    57.200
# 2014-01-01 23:00:00     23.82000       57.24  ...                 0    57.870
# ...                          ...         ...  ...               ...       ...
# 2015-06-30 19:30:00     51.99200       82.90  ...                 0    82.805
# 2015-06-30 19:45:00     51.95200       79.59  ...                 0    80.600
# 2015-06-30 20:00:00     47.01600       73.71  ...                 0    75.075
# 2015-06-30 22:15:00     30.95992       65.16  ...                 0    65.165
# 2015-06-30 22:45:00     35.97594       67.84  ...                 0    68.045
#
# [34325 rows x 16 columns]

# %% [markdown]
# We need to add columns which are basically the same properties lagged n hours !

# %%
DF_joined = lag_gen_feature(DF_joined,"temp_avg",1,3,1)
DF_joined = lag_gen_feature(DF_joined,"consumption",1,240,24)
DF_joined = lag_gen_feature(DF_joined,"rad",3,6,1)
DF_joined.head()
# Out:
# temp_avg -1h
# temp_avg -2h
# temp_avg -3h
# consumption -1h
# consumption -25h
# consumption -49h
# consumption -73h
# consumption -97h
# consumption -121h
# consumption -145h
# consumption -169h
# consumption -193h
# consumption -217h
# rad -3h
# rad -4h
# rad -5h
# rad -6h
#                      consumption  temp_set_1  ...  rad -5h  rad -6h
# 2014-01-15 13:00:00      35.5125       67.01  ...    496.0    479.8
# 2014-01-15 13:15:00      38.8700       67.55  ...    508.7    496.0
# 2014-01-15 13:30:00      37.8250       68.38  ...    516.7    508.7
# 2014-01-15 13:45:00      37.8525       69.89  ...    522.5    516.7
# 2014-01-15 14:00:00      41.7275       70.50  ...    520.4    522.5
#
# [5 rows x 33 columns]

# %%
def maxInColumn(df,column):
  max=df.loc[:,column].max()
  return(max)

def minInColumn(df,column):
  min=df.loc[:,column].min()
  return(min)

# %%
  max_rad=maxInColumn(DF_joined,"rad")
  DF_joined.loc[:,"scaled_rad"] = DF_joined.loc[:,"rad"]/max_rad
  
  base_cons=minInColumn(DF_joined,"consumption")
  DF_joined.loc[:,"reduced_cons"] = DF_joined.loc[:,"consumption"]-base_cons
  max_cons_red=maxInColumn(DF_joined,"reduced_cons")
  DF_joined.loc[:,"scaled_cons_red"] = DF_joined.loc[:,"reduced_cons"]/max_cons_red

# %%
# as we seen in the class, we add a feature regarding the comfort temperature of a weather sensitive buildings ASHRAE Standard 55
# at the moment, we are not even know what is the conditioning system used; the generated feature might be a clue for us
DF_joined.loc[:,"temp_avg_degc"] = (DF_joined.loc[:,"temp_avg"]-32)*(5/9)
DF_joined.loc[:,"temp_avg_comfort"]=DF_joined.loc[:,"temp_avg_degc"]*0.31+17.8

max_cons=maxInColumn(DF_joined,"consumption")
max_cons
# Out:
# 224287.3881

# %% [markdown]
# As can be seen from the first cleaning of Data there are some irrational data in the consumotion data. the next section finds out and removes this set of data

# %% [markdown]
# Use pd.concat followed by drop_duplicates(keep=False)
# pd.concat([df1, df2, df2]).drop_duplicates(keep=False)
# pd.concat adds the two DataFrames together by appending one right after the other. if there is any overlap, it will be captured by the drop_duplicates method. However, drop_duplicates by default leaves the first observation and removes every other observation. In this case, we want every duplicate removed. Hence, the keep=False parameter which does exactly that.
# A special note to the repeated df2. With only one df2 any row in df2 not in df1 won't be considered a duplicate and will remain. This solution with only one df2 only works when df2 is a subset of df1. However, if we concat df2 twice, it is guaranteed to be a duplicate and will subsequently be removed.

# %%
DF_joined.loc[:,"cons+1"] = DF_joined.loc[:,"consumption"].shift(1)
DF_joined.loc[:,"cons-1"] = DF_joined.loc[:,"consumption"].shift(-1)

#now we define the criteria by which we label data as unacceptable
#after some trial and error and computing the MAE and MSE, the coefficient of 1.5 turns out to be the most accurate
DF_joined.loc[:,"anomaly"] = DF_joined.loc[:,"consumption"]>1.5*0.5*(DF_joined.loc[:,"cons+1"]+DF_joined.loc[:,"cons-1"])

DF_new=DF_joined.loc[DF_joined["anomaly"]==True]
remove_target_index=DF_new.index
#remove_anomaly(DF_joined,remove_target_index,"consumption")

#DF_new=DF_series.to_frame()
# DF_new
#DF_joined
#DF_new

DF_joined=pd.concat([DF_joined,DF_new,DF_new]).drop_duplicates(keep=False)

# %%
DF_new=DF_joined.loc[DF_joined["anomaly"]==True]
DF_new
# Out:
# Empty DataFrame
# Columns: [consumption, temp_set_1, temp_set_2, RH, wind_speed, precep, rad, hour, sin(hour), cos(hour), month, dayOfWeek, weekOfYear, weekendLabel, WorkingHourLabel, temp_avg, temp_avg -1h, temp_avg -2h, temp_avg -3h, consumption -1h, consumption -25h, consumption -49h, consumption -73h, consumption -97h, consumption -121h, consumption -145h, consumption -169h, consumption -193h, consumption -217h, rad -3h, rad -4h, rad -5h, rad -6h, scaled_rad, reduced_cons, scaled_cons_red, temp_avg_degc, temp_avg_comfort, cons+1, cons-1, anomaly]
# Index: []

# %%
DF_joined_WithGeneratedFeatures = DF_joined
FileName_DF_joined_WithGeneratedFeatures = "Electricity_DF_joined_WithGeneratedFeatures.csv"
DF_joined_WithGeneratedFeatures.to_csv(FileName_DF_joined_WithGeneratedFeatures)

# %%
#gdrive_authorize()
authorizeIfLoggedOut()
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
CompleteDF_metaData = {'title' : FileName_DF_joined_WithGeneratedFeatures,"parents": [{"kind": "drive#fileLink", "id": Folder_ID_Data}] } 
CompleteDF_File = drive.CreateFile(CompleteDF_metaData) 
CompleteDF_File.SetContentFile(FileName_DF_joined_WithGeneratedFeatures) 
CompleteDF_File.Upload()

# %%
DF_joined.corr()
#this is a correlation matrix
#1 represents how much variation in one of the two is correlated to the change in the other
#if they are perfectly directly correlated it is +1; if they are perfectly inversly corellated it is -1; otherwise 0
# Out:
#                    consumption  temp_set_1  ...    cons-1  anomaly
# consumption           1.000000    0.500049  ...  0.022022      NaN
# temp_set_1            0.500049    1.000000  ...  0.007258      NaN
# temp_set_2            0.449287    0.974548  ...  0.004600      NaN
# RH                   -0.297273   -0.576375  ... -0.009062      NaN
# wind_speed            0.026678   -0.073902  ... -0.005536      NaN
# precep               -0.021035   -0.077039  ... -0.000742      NaN
# rad                   0.494506    0.485686  ...  0.001801      NaN
# hour                  0.208065    0.230277  ...  0.006321      NaN
# sin(hour)            -0.242638   -0.325267  ... -0.009079      NaN
# cos(hour)            -0.476005   -0.316330  ... -0.002865      NaN
# month                -0.015911    0.171296  ... -0.006441      NaN
# dayOfWeek            -0.236313   -0.024028  ...  0.006940      NaN
# weekOfYear            0.007982    0.218341  ... -0.006310      NaN
# weekendLabel         -0.289565   -0.023126  ...  0.007088      NaN
# WorkingHourLabel      0.484014    0.386839  ... -0.001367      NaN
# temp_avg              0.478521    0.994015  ...  0.006009      NaN
# temp_avg -1h          0.470284    0.980592  ...  0.007933      NaN
# temp_avg -2h          0.460163    0.968208  ...  0.018875      NaN
# temp_avg -3h          0.447990    0.955725  ...  0.012324      NaN
# consumption -1h       0.019992    0.026243  ...  0.000061      NaN
# consumption -25h      0.001312    0.013030  ...  0.000053      NaN
# consumption -49h      0.007437    0.005238  ...  0.000440      NaN
# consumption -73h     -0.000318   -0.004469  ...  0.000179      NaN
# consumption -97h     -0.002175   -0.003749  ...  0.000003      NaN
# consumption -121h     0.003721    0.006754  ...  0.000509      NaN
# consumption -145h    -0.005095   -0.006984  ...  0.000634      NaN
# consumption -169h    -0.003010   -0.005998  ...  0.000217      NaN
# consumption -193h     0.022510    0.005145  ...  0.000272      NaN
# consumption -217h     0.027838   -0.004237  ...  0.000137      NaN
# rad -3h               0.506680    0.524843  ...  0.008953      NaN
# rad -4h               0.504870    0.531378  ...  0.006502      NaN
# rad -5h               0.498810    0.535004  ...  0.006822      NaN
# rad -6h               0.496471    0.535387  ...  0.013479      NaN
# scaled_rad            0.494506    0.485686  ...  0.001801      NaN
# reduced_cons          1.000000    0.500049  ...  0.022022      NaN
# scaled_cons_red       1.000000    0.500049  ...  0.022022      NaN
# temp_avg_degc         0.478521    0.994015  ...  0.006009      NaN
# temp_avg_comfort      0.478521    0.994015  ...  0.006009      NaN
# cons+1                0.019992    0.026243  ...  0.000061      NaN
# cons-1                0.022022    0.007258  ...  1.000000      NaN
# anomaly                    NaN         NaN  ...       NaN      NaN
#
# [41 rows x 41 columns]

# %% [markdown]
# ### For Gas Consumption

# %%
DF_joined_Gas.loc[:,"hour"]=DF_joined_Gas.index.hour
DF_joined_Gas.head(30)
# Out:
#                      Consumption  temp_set_1  temp_set_2  ...  precep  rad  hour
# Date Time                                                 ...
# 2014-01-01 22:00:00     7.759263       57.34       57.87  ...     0.0  0.0    22
# 2014-01-01 22:15:00     8.923182       56.44       57.69  ...     0.0  0.0    22
# 2014-01-01 22:30:00    10.281476       56.23       57.36  ...     0.0  0.0    22
# 2014-01-01 22:45:00    10.475268       56.26       58.14  ...     0.0  0.0    22
# 2014-01-01 23:00:00     9.893309       57.24       58.50  ...     0.0  0.0    23
# 2014-01-01 23:15:00     9.311350       57.43       58.66  ...     0.0  0.0    23
# 2014-01-01 23:30:00     8.729389       58.08       59.29  ...     0.0  0.0    23
# 2014-01-01 23:45:00     7.565471       58.42       58.80  ...     0.0  0.0    23
# 2014-01-02 00:00:00     8.147430       56.44       56.71  ...     0.0  0.0     0
# 2014-01-02 00:15:00     9.117557       57.99       58.50  ...     0.0  0.0     0
# 2014-01-02 00:30:00     9.505140       57.70       58.26  ...     0.0  0.0     0
# 2014-01-02 00:45:00     9.311350       57.76       58.37  ...     0.0  0.0     0
# 2014-01-02 01:00:00     8.923182       57.60       58.33  ...     0.0  0.0     1
# 2014-01-02 01:15:00    10.281476       57.43       58.23  ...     0.0  0.0     1
# 2014-01-02 01:30:00    10.281476       57.31       58.68  ...     0.0  0.0     1
# 2014-01-02 01:45:00     9.699516       57.97       58.35  ...     0.0  0.0     1
# 2014-01-02 02:00:00    10.475268       57.97       58.41  ...     0.0  0.0     2
# 2014-01-02 02:15:00    12.221146       57.70       58.46  ...     0.0  0.0     2
# 2014-01-02 02:30:00    10.863435       57.20       58.71  ...     0.0  0.0     2
# 2014-01-02 02:45:00     7.759263       57.07       57.76  ...     0.0  0.0     2
# 2015-06-29 13:45:00     2.134045       68.95  ...          0          27
# 2015-06-29 14:00:00     3.685548       69.82  ...          0          27
# 2015-06-29 14:15:00     3.103589       70.38  ...          0          27
# 2015-06-29 14:30:00     2.327837       70.50  ...          0          27
# 2015-06-29 14:45:00     1.357711       69.76  ...          0          27
# 2015-06-29 15:00:00     2.134045       70.11  ...          0          27
# 2015-06-29 15:15:00     3.297963       69.96  ...          0          27
# 2015-06-29 15:30:00     3.297963       70.65  ...          0          27
# 2015-06-29 15:45:00     1.939670       70.39  ...          0          27
# 2015-06-29 16:00:00     1.357711       71.58  ...          0          27
# 2015-06-29 16:15:00     2.716004       70.81  ...          0          27
# 2015-06-29 16:30:00     2.521630       71.33  ...          0          27
# 2015-06-29 16:45:00     0.775752       71.08  ...          0          27
#
# [52 rows x 13 columns]

# %%
DF_joined_Gas.loc[:,"weekendLabel"] = DF_joined_Gas.loc[:,"dayOfWeek"].apply(WeekendDetector)
DF_joined_Gas.loc[:,"WorkingHourLabel"] = DF_joined_Gas.loc[:,"hour"].apply(workingHourDetector)
DF_joined_Gas.loc[:,"temp_avg"] = 0.5*(DF_joined_Gas.loc[:,"temp_set_1"]+DF_joined_Gas.loc[:,"temp_set_2"])

# %%
DF_joined_Gas = lag_gen_feature(DF_joined_Gas,"temp_avg",1,3,1)
DF_joined_Gas = lag_gen_feature(DF_joined_Gas,"Consumption",1,240,24)
DF_joined_Gas = lag_gen_feature(DF_joined_Gas,"rad",3,6,1)
DF_joined_Gas.head()
# Out:
# temp_avg -1h
# temp_avg -2h
# temp_avg -3h
# Consumption -1h
# Consumption -25h
# Consumption -49h
# Consumption -73h
# Consumption -97h
# Consumption -121h
# Consumption -145h
# Consumption -169h
# Consumption -193h
# Consumption -217h
# rad -3h
# rad -4h
# rad -5h
# rad -6h
#                      Consumption  temp_set_1  ...  rad -5h  rad -6h
# Date Time                                     ...
# 2014-01-13 12:45:00     5.043841       60.96  ...    494.5    479.4
# 2014-01-13 13:00:00     4.655675       61.65  ...    506.6    494.5
# 2014-01-13 13:15:00     4.073715       62.33  ...    515.9    506.6
# 2014-01-13 13:30:00     3.297963       63.37  ...    520.9    515.9
# 2014-01-13 13:45:00     3.297963       64.11  ...    522.1    520.9
#
# [5 rows x 33 columns]

# %%
def maxInColumn(df,column):
  max=df.loc[:,column].max()
  return(max)

def minInColumn(df,column):
  min=df.loc[:,column].min()
  return(min)

# %%
  max_rad_Gas=maxInColumn(DF_joined_Gas,"rad")
  DF_joined_Gas.loc[:,"scaled_rad"] = DF_joined_Gas.loc[:,"rad"]/max_rad_Gas
  
  base_cons_Gas=minInColumn(DF_joined_Gas,"Consumption")
  DF_joined_Gas.loc[:,"reduced_cons_Gas"] = DF_joined_Gas.loc[:,"Consumption"]-base_cons_Gas
  max_cons_red_Gas=maxInColumn(DF_joined_Gas,"reduced_cons_Gas")
  DF_joined_Gas.loc[:,"scaled_cons_red"] = DF_joined_Gas.loc[:,"reduced_cons_Gas"]/max_cons_red_Gas

# %%
# as we seen in the class, we add a feature regarding the comfort temperature of a weather sensitive buildings ASHRAE Standard 55
# at the moment, we are not even know what is the conditioning system used; the generated feature might be a clue for us
DF_joined_Gas.loc[:,"temp_avg_degc"] = (DF_joined_Gas.loc[:,"temp_avg"]-32)*(5/9)
DF_joined_Gas.loc[:,"temp_avg_comfort"]=DF_joined_Gas.loc[:,"temp_avg_degc"]*0.31+17.8

max_cons_Gas=maxInColumn(DF_joined_Gas,"Consumption")
max_cons_Gas
# Out:
# 28.904172999999997

# %%
DF_joined_Gas.loc[:,"cons+1"] = DF_joined_Gas.loc[:,"Consumption"].shift(1)
DF_joined_Gas.loc[:,"cons-1"] = DF_joined_Gas.loc[:,"Consumption"].shift(-1)

#now we define the criteria by which we label data as unacceptable
#after some trial and error and computing the MAE and MSE, the coefficient of 1.5 turns out to be the most accurate
DF_joined_Gas.loc[:,"anomaly"] = DF_joined_Gas.loc[:,"Consumption"]>1.5*0.5*(DF_joined_Gas.loc[:,"cons+1"]+DF_joined_Gas.loc[:,"cons-1"])
DF_new_Gas=DF_joined_Gas.loc[DF_joined_Gas["anomaly"]==True]
remove_target_index_Gas=DF_new_Gas.index
DF_joined_Gas=pd.concat([DF_joined_Gas,DF_new_Gas,DF_new_Gas]).drop_duplicates(keep=False)

# %% [markdown]
# # Final Cleaning of data sets.
# Lets take a final look and remove the unwanted generated features in the process.
#
# During the process of cleaning data, we generated some forms of consumption which are scaled forms of the consumption value itself. These should be removed because they make the guessing of the values unmeaningful (cause we are actually presenting almost the same value of consumption with different forms in both the target and features)

# %% [markdown]
# ##Cleaning unacceptable Electricity Consumptions

# %% [markdown]
# DF_joined

# %%
remove_feature(DF_joined,"scaled_cons_red")
remove_feature(DF_joined,"anomaly")
remove_feature(DF_joined,"anomaly+1")
remove_feature(DF_joined,"anomaly-1")
remove_feature(DF_joined,"cons -1")
remove_feature(DF_joined,"cons_+1")
remove_feature(DF_joined,"cons-1")
remove_feature(DF_joined,"cons+1")
remove_feature(DF_joined,"consm1")
remove_feature(DF_joined,"consp1")
 

DF_joined
# Out:
# scaled_cons_red was removed succesfully from the dataframe
# anomaly was removed succesfully from the dataframe
# cons-1 was removed succesfully from the dataframe
# cons+1 was removed succesfully from the dataframe
#                      consumption  temp_set_1  ...  temp_avg_degc  temp_avg_comfort
# 2014-01-15 13:15:00     38.87000       67.55  ...      19.580556         23.869972
# 2014-01-15 13:30:00     37.82500       68.38  ...      20.061111         24.018944
# 2014-01-15 13:45:00     37.85250       69.89  ...      20.769444         24.238528
# 2014-01-15 14:00:00     41.72750       70.50  ...      21.058333         24.328083
# 2014-01-15 14:15:00     40.17750       70.57  ...      21.077778         24.334111
# ...                          ...         ...  ...            ...               ...
# 2015-06-30 18:30:00     37.97601       75.04  ...      23.766667         25.167667
# 2015-06-30 19:30:00     51.99200       82.90  ...      28.225000         26.549750
# 2015-06-30 19:45:00     51.95200       79.59  ...      27.000000         26.170000
# 2015-06-30 20:00:00     47.01600       73.71  ...      23.930556         25.218472
# 2015-06-30 22:15:00     30.95992       65.16  ...      18.425000         23.511750
#
# [33050 rows x 37 columns]

# %% [markdown]
# ##Cleaning unacceptable Gas Consumptions

# %%
remove_feature(DF_joined_Gas,"scaled_cons_red")
remove_feature(DF_joined_Gas,"anomaly")
remove_feature(DF_joined_Gas,"anomaly+1")
remove_feature(DF_joined_Gas,"anomaly-1")
remove_feature(DF_joined_Gas,"cons -1")
remove_feature(DF_joined_Gas,"cons_+1")
remove_feature(DF_joined_Gas,"cons-1")
remove_feature(DF_joined_Gas,"cons+1")
remove_feature(DF_joined_Gas,"consm1")
remove_feature(DF_joined_Gas,"consp1")
DF_joined_Gas
# Out:
# scaled_cons_red was removed succesfully from the dataframe
# anomaly was removed succesfully from the dataframe
# cons-1 was removed succesfully from the dataframe
# cons+1 was removed succesfully from the dataframe
#                      Consumption  temp_set_1  ...  temp_avg_degc  temp_avg_comfort
# Date Time                                     ...
# 2014-01-13 13:00:00     4.655675       61.65  ...      16.166667         22.811667
# 2014-01-13 13:15:00     4.073715       62.33  ...      16.575000         22.938250
# 2014-01-13 13:30:00     3.297963       63.37  ...      17.094444         23.099278
# 2014-01-13 13:45:00     3.297963       64.11  ...      17.438889         23.206056
# 2014-01-13 14:00:00     2.909797       64.15  ...      17.516667         23.230167
# ...                          ...         ...  ...            ...               ...
# 2015-06-29 15:30:00     3.297963       70.65  ...      21.130556         24.350472
# 2015-06-29 15:45:00     1.939670       70.39  ...      20.983333         24.304833
# 2015-06-29 16:00:00     1.357711       71.58  ...      21.688889         24.523556
# 2015-06-29 16:15:00     2.716004       70.81  ...      21.311111         24.406444
# 2015-06-29 16:30:00     2.521630       71.33  ...      21.550000         24.480500
#
# [50471 rows x 37 columns]

# %% [markdown]
# # Learning Process

# %% [markdown]
# ## Defining Target and features

# %% [markdown]
# ### Define for Electricity Consumption

# %%
DF_joined=DF_joined.dropna()

DF_target= DF_joined["consumption"] # I am actually making a series , we could also use double brackets
DF_features= DF_joined.drop("consumption", axis=1) # I am actually m.dropaking a series , we could also use double brackets

#note that the value of reduced_cons is actually directly referring to the consumption with a different form. as it can make the learning biased, it should be removed from the features.
DF_features= DF_features.drop("reduced_cons", axis=1)

DF_target
#DF_features
# Out:
# 2014-01-15 13:15:00    38.87000
# 2014-01-15 13:30:00    37.82500
# 2014-01-15 13:45:00    37.85250
# 2014-01-15 14:00:00    41.72750
# 2014-01-15 14:15:00    40.17750
#                          ...
# 2015-06-30 18:30:00    37.97601
# 2015-06-30 19:30:00    51.99200
# 2015-06-30 19:45:00    51.95200
# 2015-06-30 20:00:00    47.01600
# 2015-06-30 22:15:00    30.95992
# Name: consumption, Length: 33050, dtype: float64

# %% [markdown]
# ### Define for Gas Consumption

# %%
DF_joined_Gas=DF_joined_Gas.dropna()

DF_target_Gas= DF_joined_Gas["Consumption"] # I am actually making a series , we could also use double brackets
DF_features_Gas= DF_joined_Gas.drop("Consumption", axis=1) # I am actually m.dropaking a series , we could also use double brackets

#note that the value of reduced_cons_Gas is actually directly referring to the consumption with a different form. as it can make the learning biased, it should be removed from the features.
DF_features_Gas= DF_features_Gas.drop("reduced_cons_Gas", axis=1)
#DF_features_Gas= DF_features_Gas.drop("reduced_cons", axis=1)
DF_target_Gas
DF_features_Gas
# Out:
#                      temp_set_1  temp_set_2  ...  temp_avg_degc  temp_avg_comfort
# Date Time                                    ...
# 2014-01-13 13:00:00       61.65       60.55  ...      16.166667         22.811667
# 2014-01-13 13:15:00       62.33       61.34  ...      16.575000         22.938250
# 2014-01-13 13:30:00       63.37       62.17  ...      17.094444         23.099278
# 2014-01-13 13:45:00       64.11       62.67  ...      17.438889         23.206056
# 2014-01-13 14:00:00       64.15       62.91  ...      17.516667         23.230167
# ...                         ...         ...  ...            ...               ...
# 2015-06-29 15:30:00       70.65       69.42  ...      21.130556         24.350472
# 2015-06-29 15:45:00       70.39       69.15  ...      20.983333         24.304833
# 2015-06-29 16:00:00       71.58       70.50  ...      21.688889         24.523556
# 2015-06-29 16:15:00       70.81       69.91  ...      21.311111         24.406444
# 2015-06-29 16:30:00       71.33       70.25  ...      21.550000         24.480500
#
# [50471 rows x 35 columns]

# %% [markdown]
# ## Apply Learning Models to Electricity Consumption

# %% [markdown]
# ### Train Test Split Method, Linear Regression

# %% [markdown]
# using Scikit learn to create train and text datasets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(DF_features,DF_target,test_size=0.2, random_state=41234)

# %%
from sklearn import linear_model
linear_reg = linear_model.LinearRegression()

# %%
linear_reg.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#Attention!: the output of the above line is an array which has to be converted to a DataFrame using the following command.
#Attention!: meanwhile I was cleaning data sets, after removing irrelevant data, some NaN fields was formed which made inconsistency with the learning model.
           # After finishing process on your feature-generated data set, use "dropna" once again to make sure data set is consistent with the learning model.

!
from sklearn.model_selection import train_test_split 
X_train, X_test, Y_train, Y_test = train_test_split(DF_features,DF_target,test_size = 0.2, random_state=41234)

from sklearn import linear_model
linear_reg = linear_model.LinearRegression()

# The second step will be fitting a model
linear_reg.fit(X_train, Y_train)
predicted_linearReg_split = linear_reg.predict(X_test)

predicted_DF_linearReg_split=pd.DataFrame(predicted_linearReg_split,index=Y_test.index, columns=["EE_cons_predicted_linearReg_split"])
predicted_DF_linearReg_split=predicted_DF_linearReg_split.join(Y_test)
predicted_DF_linearReg_split
# Out:
#                      EE_cons_predicted_linearReg_split  consumption
# 2014-03-25 07:15:00                          28.852671     27.84384
# 2014-08-12 17:45:00                          36.207683     36.79274
# 2014-08-17 20:45:00                          26.512068     28.99874
# 2015-01-12 07:00:00                          28.903506     32.10836
# 2014-08-14 11:30:00                          37.035938     39.48862
# ...                                                ...          ...
# 2014-04-04 12:00:00                          32.745761     33.36013
# 2015-05-05 10:15:00                          36.719011     32.99200
# 2014-08-06 05:30:00                          31.512201     30.13477
# 2014-11-02 13:45:00                          33.156939     29.59965
# 2014-12-25 06:30:00                          24.788780     29.19645
#
# [6610 rows x 2 columns]

# %%
predicted_DF_linearReg_split_sept_week1=predicted_DF_linearReg_split.loc['2014-09-01':'2014-09-08']
predicted_DF_linearReg_split_sept_week1.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
MAE_linearReg_split = mean_absolute_error(predicted_linearReg_split,y_test)
MSE_linearReg_split = mean_squared_error(predicted_linearReg_split,y_test)
R2_linear_split=r2_score(predicted_linearReg_split,y_test)
print('MAE : ' + str(MAE_linearReg_split))
print('MSE : ' + str(MSE_linearReg_split))
print('R2 : ' + str(R2_linear_split))
# Out:
# MAE : 3.3371682141942998
# MSE : 2589.129079775016
# R2 : 0.01026858510164308

# %% [markdown]
# ###Cross Validation Method, Linear Regression

# %%
from sklearn.model_selection import cross_val_predict
predict_linearReg_CV = cross_val_predict(linear_reg,DF_features,DF_target)

# %% [markdown]
# Pay attention that the latter gives us prediction for all of the rows

# %%
predicted_DF_linearReg_CV = pd.DataFrame(predict_linearReg_CV, index=DF_target.index, columns=["EE_cons_predicted_linearReg_CV"])
predicted_DF_linearReg_CV.head(24)
# Out:
#                      EE_cons_predicted_linearReg_CV
# 2014-01-15 13:15:00                       41.252861
# 2014-01-15 13:30:00                       41.499718
# 2014-01-15 13:45:00                       41.771805
# 2014-01-15 14:00:00                       41.985298
# 2014-01-15 14:15:00                       42.176956
# 2014-01-15 14:30:00                       42.269440
# 2014-01-15 14:45:00                       42.247040
# 2014-01-15 15:00:00                       41.982296
# 2014-01-15 15:15:00                       42.050453
# 2014-01-15 15:30:00                       42.026176
# 2014-01-15 15:45:00                       42.084145
# 2014-01-15 16:00:00                       41.554276
# 2014-01-15 16:15:00                       41.476227
# 2014-01-15 16:30:00                       41.301098
# 2014-01-15 16:45:00                       41.169800
# 2014-01-15 17:00:00                       40.444267
# 2014-01-15 17:15:00                       40.368088
# 2014-01-15 17:30:00                       40.231285
# 2014-01-15 17:45:00                       40.017406
# 2014-01-15 18:00:00                       38.300739
# 2014-01-15 18:15:00                       37.983654
# 2014-01-15 18:30:00                       37.986115
# 2014-01-15 19:00:00                       36.743874
# 2014-01-15 19:30:00                       36.683136

# %%
predicted_DF_linearReg_CV=predicted_DF_linearReg_CV.join(DF_target)
predicted_DF_linearReg_CV
# Out:
#                      EE_cons_predicted_linearReg_CV  consumption
# 2014-01-15 13:15:00                       41.252861     38.87000
# 2014-01-15 13:30:00                       41.499718     37.82500
# 2014-01-15 13:45:00                       41.771805     37.85250
# 2014-01-15 14:00:00                       41.985298     41.72750
# 2014-01-15 14:15:00                       42.176956     40.17750
# ...                                             ...          ...
# 2015-06-30 18:30:00                       42.311310     37.97601
# 2015-06-30 19:30:00                       40.534912     51.99200
# 2015-06-30 19:45:00                       43.369110     51.95200
# 2015-06-30 20:00:00                       41.663055     47.01600
# 2015-06-30 22:15:00                       47.389893     30.95992
#
# [33052 rows x 2 columns]

# %%
predicted_DF_linearReg_CV_sept_week1=predicted_DF_linearReg_split.loc['2014-09-01':'2014-09-08']
predicted_DF_linearReg_CV_sept_week1.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
MAE_linearReg_CV = mean_absolute_error(predict_linearReg_CV,DF_target)
MSE_linearReg_CV = mean_squared_error(predict_linearReg_CV,DF_target)
R2_linear_CV=r2_score(predict_linearReg_CV,DF_target)
print('MAE : ' + str(MAE_linearReg_CV))
print('MSE : ' + str(MSE_linearReg_CV))
print('R2 : ' + str(R2_linear_CV))
# Out:
# MAE : 5.5394506552715175
# MSE : 84416.34380461082
# R2 : 0.0005667778710184423

# %% [markdown]
# ### Cross Validation Method, Random Forrest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
RF_reg = RandomForestRegressor()

# %%
predict_RF_reg_CV = cross_val_predict(RF_reg,DF_features,DF_target, cv=10)

# %%
Predicted_DF_RF_reg_CV = pd.DataFrame(predict_RF_reg_CV, index= DF_target.index, columns=["EE_cons_predicted_RF_reg_CV"])
Predicted_DF_RF_reg_CV.head(24)
# Out:
#                      EE_cons_predicted_RF_reg_CV
# 2014-01-15 13:15:00                    37.252430
# 2014-01-15 13:30:00                    39.670632
# 2014-01-15 13:45:00                    38.920896
# 2014-01-15 14:00:00                    39.432432
# 2014-01-15 14:15:00                    49.732257
# 2014-01-15 14:30:00                    41.635019
# 2014-01-15 14:45:00                    38.738263
# 2014-01-15 15:00:00                    48.186056
# 2014-01-15 15:15:00                    39.056704
# 2014-01-15 15:30:00                    37.360184
# 2014-01-15 15:45:00                    42.451283
# 2014-01-15 16:00:00                    50.103408
# 2014-01-15 16:15:00                    51.318417
# 2014-01-15 16:30:00                    49.985864
# 2014-01-15 16:45:00                    41.043203
# 2014-01-15 17:00:00                    41.379236
# 2014-01-15 17:15:00                    37.913371
# 2014-01-15 17:30:00                    40.985588
# 2014-01-15 17:45:00                    38.273073
# 2014-01-15 18:00:00                    35.280589
# 2014-01-15 18:15:00                    35.834550
# 2014-01-15 18:30:00                    34.892450
# 2014-01-15 19:00:00                    33.477620
# 2014-01-15 19:30:00                    33.924647

# %%
Predicted_DF_RF_reg_CV=Predicted_DF_RF_reg_CV.join(DF_target)

# %%
Predicted_DF_RF_reg_CV.head(20)
# Out:
#                      EE_cons_predicted_RF_reg_CV  consumption
# 2014-01-15 13:15:00                    37.252430      38.8700
# 2014-01-15 13:30:00                    39.670632      37.8250
# 2014-01-15 13:45:00                    38.920896      37.8525
# 2014-01-15 14:00:00                    39.432432      41.7275
# 2014-01-15 14:15:00                    49.732257      40.1775
# 2014-01-15 14:30:00                    41.635019      37.6475
# 2014-01-15 14:45:00                    38.738263      42.4025
# 2014-01-15 15:00:00                    48.186056      38.6725
# 2014-01-15 15:15:00                    39.056704      37.7675
# 2014-01-15 15:30:00                    37.360184      40.4325
# 2014-01-15 15:45:00                    42.451283      41.8500
# 2014-01-15 16:00:00                    50.103408      40.7400
# 2014-01-15 16:15:00                    51.318417      41.7525
# 2014-01-15 16:30:00                    49.985864      39.3700
# 2014-01-15 16:45:00                    41.043203      40.0725
# 2014-01-15 17:00:00                    41.379236      38.9125
# 2014-01-15 17:15:00                    37.913371      40.1650
# 2014-01-15 17:30:00                    40.985588      38.8525
# 2014-01-15 17:45:00                    38.273073      36.3925
# 2014-01-15 18:00:00                    35.280589      36.8050

# %% [markdown]
# Predicted_DF_RF_reg_CV_august = Predicted_DF_RF_reg_CV.loc["2014-08-01":"2014-08-08",:]
# Predicted_DF_RF_reg_CV_august.plot()

# %%
MAE_RF_reg_CV= mean_absolute_error(predict_RF_reg_CV,DF_target)
MSE_RF_reg_CV= mean_squared_error(predict_RF_reg_CV,DF_target)
R2_RF_reg_CV = r2_score(predict_RF_reg_CV,DF_target)
print("MAE CV:"+str(MAE_RF_reg_CV))
print("MSE CV:"+ str(MSE_RF_reg_CV))
#
# [33050 rows x 0 columns]

# %% [markdown]
# We eant to assign a one month training period. the "prediction" period starts one month after the first time stamp measured, and lasts to the final day.

# %%
firstTimeStampMeasured
# Out:
# Timestamp('2014-01-15 13:15:00')

# %%
lastTimeStampMeasured
# Out:
# Timestamp('2015-06-30 22:15:00')

# %%
periodOfTraining = pd.Timedelta(30, unit="d")
periodOfTraining
# Out:
# Timedelta('30 days 00:00:00')

# %%
FirstTimeStampToPredict = firstTimeStampMeasured + periodOfTraining
FirstTimeStampToPredict
# Out:
# Timestamp('2014-02-14 13:15:00')

# %%
trainingStartTimeStamp = firstTimeStampMeasured
trainingEndTimeStamp = FirstTimeStampToPredict - pd.Timedelta(1,unit="h")

# %%
trainingStartTimeStamp
# Out:
# Timestamp('2014-01-15 13:15:00')

# %%
trainingEndTimeStamp
# Out:
# Timestamp('2014-02-14 12:15:00')

# %%
DF_onlineConsumptionPrediction=DF_onlineConsumptionPrediction.sort_index()
DF_onlineConsumptionPrediction
# Out:
# Empty DataFrame
# Columns: []
# Index: [2014-01-15 13:15:00, 2014-01-15 13:30:00, 2014-01-15 13:45:00, 2014-01-15 14:00:00, 2014-01-15 14:15:00, 2014-01-15 14:30:00, 2014-01-15 14:45:00, 2014-01-15 15:00:00, 2014-01-15 15:15:00, 2014-01-15 15:30:00, 2014-01-15 15:45:00, 2014-01-15 16:00:00, 2014-01-15 16:15:00, 2014-01-15 16:30:00, 2014-01-15 16:45:00, 2014-01-15 17:00:00, 2014-01-15 17:15:00, 2014-01-15 17:30:00, 2014-01-15 17:45:00, 2014-01-15 18:00:00, 2014-01-15 18:15:00, 2014-01-15 18:30:00, 2014-01-15 19:00:00, 2014-01-15 19:30:00, 2014-01-15 19:45:00, 2014-01-15 20:15:00, 2014-01-15 20:30:00, 2014-01-15 20:45:00, 2014-01-15 21:15:00, 2014-01-15 21:45:00, 2014-01-15 22:00:00, 2014-01-15 22:15:00, 2014-01-15 22:30:00, 2014-01-15 22:45:00, 2014-01-15 23:00:00, 2014-01-15 23:15:00, 2014-01-15 23:30:00, 2014-01-16 00:30:00, 2014-01-16 00:45:00, 2014-01-16 01:00:00, 2014-01-16 01:15:00, 2014-01-16 01:45:00, 2014-01-16 02:00:00, 2014-01-16 02:15:00, 2014-01-16 02:30:00, 2014-01-16 02:45:00, 2014-01-16 03:00:00, 2014-01-16 03:30:00, 2014-01-16 03:45:00, 2014-01-16 04:00:00, 2014-01-16 04:15:00, 2014-01-16 04:30:00, 2014-01-16 05:00:00, 2014-01-16 05:15:00, 2014-01-16 05:45:00, 2014-01-16 06:00:00, 2014-01-16 06:30:00, 2014-01-16 06:45:00, 2014-01-16 07:30:00, 2014-01-16 07:45:00, 2014-01-16 08:00:00, 2014-01-16 08:30:00, 2014-01-16 08:45:00, 2014-01-16 09:00:00, 2014-01-16 09:15:00, 2014-01-16 09:45:00, 2014-01-16 10:00:00, 2014-01-16 10:30:00, 2014-01-16 10:45:00, 2014-01-16 11:00:00, 2014-01-16 11:15:00, 2014-01-16 11:30:00, 2014-01-16 11:45:00, 2014-01-16 12:00:00, 2014-01-16 12:15:00, 2014-01-16 12:30:00, 2014-01-16 12:45:00, 2014-01-16 13:00:00, 2014-01-16 13:15:00, 2014-01-16 13:30:00, 2014-01-16 13:45:00, 2014-01-16 14:00:00, 2014-01-16 14:15:00, 2014-01-16 14:30:00, 2014-01-16 14:45:00, 2014-01-16 15:00:00, 2014-01-16 15:15:00, 2014-01-16 15:30:00, 2014-01-16 15:45:00, 2014-01-16 16:00:00, 2014-01-16 16:15:00, 2014-01-16 16:30:00, 2014-01-16 16:45:00, 2014-01-16 17:00:00, 2014-01-16 17:15:00, 2014-01-16 17:30:00, 2014-01-16 17:45:00, 2014-01-16 18:00:00, 2014-01-16 18:30:00, 2014-01-16 18:45:00, ...]
#
# [33050 rows x 0 columns]

# %%
DF_onlineConsumptionPrediction = DF_onlineConsumptionPrediction.truncate(before=FirstTimeStampToPredict)    
DF_onlineConsumptionPrediction.index
# Out:
# DatetimeIndex(['2014-02-14 13:15:00', '2014-02-14 13:30:00',
#                '2014-02-14 13:45:00', '2014-02-14 14:00:00',
#                '2014-02-14 14:30:00', '2014-02-14 14:45:00',
#                '2014-02-14 15:00:00', '2014-02-14 15:15:00',
#                '2014-02-14 15:45:00', '2014-02-14 16:30:00',
#                ...
#                '2015-06-30 16:45:00', '2015-06-30 17:00:00',
#                '2015-06-30 17:30:00', '2015-06-30 17:45:00',
#                '2015-06-30 18:15:00', '2015-06-30 18:30:00',
#                '2015-06-30 19:30:00', '2015-06-30 19:45:00',
#                '2015-06-30 20:00:00', '2015-06-30 22:15:00'],
#               dtype='datetime64[ns]', length=31321, freq=None)

# %% [markdown]
# First, we need to change DataFrames to numpy array so we use the function   "DataFrame.values" which return a Numpy representation of the DataFrame.
#
# Second, some info about what the shape of a numpy array is:
#
# for a 1D array, the shape would be (n,) where n is the number of elements in your array.
#
# For a 2D array, the shape would be (n,m) where n is the number of rows and m is the number of columns in your array.
#
# The shape property is usually used to get the current shape of an array, but may also be used to reshape the array in-place by assigning a tuple of array dimensions to it. As with numpy.reshape, one of the new shape dimensions can be -1, in which case its value is inferred from the size of the array and the remaining dimensions. Reshaping an array in-place will fail if a copy is required.
#
# trying to reshape with (-1, 1) . We have provided column as 1 but rows as unknown
#
# ==> Reshape your data using array.reshape(-1, 1) if your data has a single feature

# %%
DF_target
# Out:
# 2014-01-15 13:15:00    38.87000
# 2014-01-15 13:30:00    37.82500
# 2014-01-15 13:45:00    37.85250
# 2014-01-15 14:00:00    41.72750
# 2014-01-15 14:15:00    40.17750
#                          ...
# 2015-06-30 18:30:00    37.97601
# 2015-06-30 19:30:00    51.99200
# 2015-06-30 19:45:00    51.95200
# 2015-06-30 20:00:00    47.01600
# 2015-06-30 22:15:00    30.95992
# Name: consumption, Length: 33050, dtype: float64

# %% [markdown]
# as we can see, DF_target is in a form of a panda series not a data frame, so we use ".to_frame" function to make it in the form of data frame.

# %%
DF_target_reshaped=DF_target.to_frame()
DF_target_reshaped
# Out:
#                      consumption
# 2014-01-15 13:15:00     38.87000
# 2014-01-15 13:30:00     37.82500
# 2014-01-15 13:45:00     37.85250
# 2014-01-15 14:00:00     41.72750
# 2014-01-15 14:15:00     40.17750
# ...                          ...
# 2015-06-30 18:30:00     37.97601
# 2015-06-30 19:30:00     51.99200
# 2015-06-30 19:45:00     51.95200
# 2015-06-30 20:00:00     47.01600
# 2015-06-30 22:15:00     30.95992
#
# [33050 rows x 1 columns]

# %%
DF_target2 = DF_joined.loc[:,["consumption"]]
DF_target2
# Out:
#                      consumption
# 2014-01-15 13:15:00     38.87000
# 2014-01-15 13:30:00     37.82500
# 2014-01-15 13:45:00     37.85250
# 2014-01-15 14:00:00     41.72750
# 2014-01-15 14:15:00     40.17750
# ...                          ...
# 2015-06-30 18:30:00     37.97601
# 2015-06-30 19:30:00     51.99200
# 2015-06-30 19:45:00     51.95200
# 2015-06-30 20:00:00     47.01600
# 2015-06-30 22:15:00     30.95992
#
# [33050 rows x 1 columns]

# %%
DF_joined.index
# Out:
# DatetimeIndex(['2014-01-15 13:15:00', '2014-01-15 13:30:00',
#                '2014-01-15 13:45:00', '2014-01-15 14:00:00',
#                '2014-01-15 14:15:00', '2014-01-15 14:30:00',
#                '2014-01-15 14:45:00', '2014-01-15 15:00:00',
#                '2014-01-15 15:15:00', '2014-01-15 15:30:00',
#                ...
#                '2015-06-30 16:45:00', '2015-06-30 17:00:00',
#                '2015-06-30 17:30:00', '2015-06-30 17:45:00',
#                '2015-06-30 18:15:00', '2015-06-30 18:30:00',
#                '2015-06-30 19:30:00', '2015-06-30 19:45:00',
#                '2015-06-30 20:00:00', '2015-06-30 22:15:00'],
#               dtype='datetime64[ns]', length=33050, freq=None)

# %%
timeStampToPredict = FirstTimeStampToPredict  #means start one month (period of training) after the first time stamp measured
while(timeStampToPredict <= lastTimeStampMeasured): #do it from one month after the first time stamp measured to the last time stamp
  if timeStampToPredict in DF_joined.index:
    DF_features_train = DF_features.truncate(before=trainingStartTimeStamp, after=trainingEndTimeStamp) #from features in one month training period, remove whatever is outside this month
    DF_target_train = DF_target.truncate(before=trainingStartTimeStamp, after=trainingEndTimeStamp) #from target in one month training period, remove whatever is outside this month
    DF_features_test = DF_features.loc[timeStampToPredict,:].values.reshape(1,-1)    # reshape the values into standard numpy array form
    DF_target_test = DF_target2.loc[timeStampToPredict,"consumption"]  
    #lets train
    #RF_reg.fit(DF_features_train,DF_target_train)
    #linear_reg.fit(DF_features_train,DF_target_train)
    #predicted_consumption = RF_reg.predict(DF_feature_test)
    predicted_consumption = linear_reg.predict(DF_features_test)
    DF_onlineConsumptionPrediction.loc[timeStampToPredict,"Predicted"] = predicted_consumption
    DF_onlineConsumptionPrediction.loc[timeStampToPredict,"Real"] = DF_target_test
  else:
    pass


  timeStampToPredict = timeStampToPredict + pd.Timedelta(1,unit="h")  # the indicator is updated by one hour
  #now we have to shift forward the "one month training period" by an hour to make sure we use all the data set once as training.
  trainingStartTimeStamp = trainingStartTimeStamp + pd.Timedelta(1,unit="h")
  trainingEndTimeStamp = trainingEndTimeStamp + pd.Timedelta(1,unit="h")

# %%
DF_onlineConsumptionPrediction.dropna(inplace=True)

# %% [markdown]
# ## Apply Learning Models to Gas Consumption

# %% [markdown]
# ### Train Test Split Method, Linear Regression

# %%
DF_target_Gas
# Out:
# Date Time
# 2014-01-13 13:00:00    4.655675
# 2014-01-13 13:15:00    4.073715
# 2014-01-13 13:30:00    3.297963
# 2014-01-13 13:45:00    3.297963
# 2014-01-13 14:00:00    2.909797
#                          ...
# 2015-06-29 15:30:00    3.297963
# 2015-06-29 15:45:00    1.939670
# 2015-06-29 16:00:00    1.357711
# 2015-06-29 16:15:00    2.716004
# 2015-06-29 16:30:00    2.521630
# Name: Consumption, Length: 50471, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train2, X_test2, Y_train2, Y_test2 = train_test_split(DF_features_Gas,DF_target_Gas,test_size=0.21, random_state=44234)

# %%
from sklearn import linear_model
linear_reg_Gas= linear_model.LinearRegression()

# %%
linear_reg_Gas.fit(X_train2,Y_train2)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
linear_reg_Gas.fit(X_train2, Y_train2)
predicted_linearReg_split_Gas = linear_reg_Gas.predict(X_test2)

predicted_DF_linearReg_split_Gas=pd.DataFrame(predicted_linearReg_split_Gas,index=Y_test2.index, columns=["EE_cons_predicted_linearReg_split"])
predicted_DF_linearReg_split_Gas=predicted_DF_linearReg_split_Gas.join(Y_test2)
predicted_DF_linearReg_split_Gas
# Out:
#                      EE_cons_predicted_linearReg_split  Consumption
# Date Time
# 2014-03-31 08:30:00                          15.796928    13.967024
# 2015-02-10 00:15:00                           9.653526    10.863435
# 2014-09-29 06:15:00                           6.342079     7.177304
# 2014-06-21 18:00:00                           3.688629     3.103589
# 2014-11-12 16:45:00                           3.948601     4.461882
# ...                                                ...          ...
# 2014-12-04 12:15:00                           4.313698     2.716004
# 2015-04-20 18:30:00                           7.214821     6.595345
# 2014-11-07 11:45:00                           2.005142     1.939670
# 2014-04-26 01:30:00                          13.673973    13.967024
# 2014-05-14 19:30:00                           2.555695     5.819593
#
# [10599 rows x 2 columns]

# %%
predicted_DF_linearReg_split_sept_week1=predicted_DF_linearReg_split_Gas.loc['2014-09-01':'2014-09-08']
predicted_DF_linearReg_split_sept_week1.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
MAE_linearReg_split_Gas = mean_absolute_error(predicted_linearReg_split_Gas,Y_test2)
MSE_linearReg_split_Gas = mean_squared_error(predicted_linearReg_split_Gas,Y_test2)
R2_linear_split_Gas=r2_score(predicted_linearReg_split_Gas,Y_test2)
print('MAE : ' + str(MAE_linearReg_split_Gas))
print('MSE : ' + str(MSE_linearReg_split_Gas))
print('R2 : ' + str(R2_linear_split_Gas))
# Out:
# MAE : 0.8456297270054663
# MSE : 1.3174764227749927
# R2 : 0.9257680887078866

# %% [markdown]
# ###Cross Validation Method, Linear Regression

# %%
from sklearn.model_selection import cross_val_predict
predict_linearReg_CV_Gas = cross_val_predict(linear_reg_Gas,DF_features_Gas,DF_target_Gas)

# %%
predicted_DF_linearReg_CV_Gas = pd.DataFrame(predict_linearReg_CV_Gas, index=DF_target_Gas.index, columns=["EE_cons_predicted_linearReg_CV_Gas"])
predicted_DF_linearReg_CV_Gas.head(24)
# Out:
#                      EE_cons_predicted_linearReg_CV_Gas
# Date Time
# 2014-01-13 13:00:00                            5.253647
# 2014-01-13 13:15:00                            4.979309
# 2014-01-13 13:30:00                            4.415848
# 2014-01-13 13:45:00                            3.721100
# 2014-01-13 14:00:00                            3.651154
# 2014-01-13 14:15:00                            3.354584
# 2014-01-13 14:30:00                            2.823303
# 2014-01-13 14:45:00                            2.691681
# 2014-01-13 15:00:00                            2.720428
# 2014-01-13 15:15:00                            2.625214
# 2014-01-13 15:30:00                            2.430466
# 2014-01-13 15:45:00                            2.576202
# 2014-01-13 16:00:00                            2.933899
# 2014-01-13 16:15:00                            3.015778
# 2014-01-13 16:30:00                            3.043961
# 2014-01-13 16:45:00                            3.302063
# 2014-01-13 17:00:00                            4.126678
# 2014-01-13 17:15:00                            4.725891
# 2014-01-13 17:30:00                            5.791809
# 2014-01-13 17:45:00                            6.869385
# 2014-01-13 18:00:00                            5.814026
# 2014-01-13 18:15:00                            5.173676
# 2014-01-13 18:30:00                            5.697754
# 2014-01-13 18:45:00                            5.895340

# %%
predicted_DF_linearReg_CV_Gas=predicted_DF_linearReg_CV_Gas.join(DF_target_Gas)
predicted_DF_linearReg_CV_Gas
# Out:
#                      EE_cons_predicted_linearReg_CV_Gas  Consumption
# Date Time
# 2014-01-13 13:00:00                            5.253647     4.655675
# 2014-01-13 13:15:00                            4.979309     4.073715
# 2014-01-13 13:30:00                            4.415848     3.297963
# 2014-01-13 13:45:00                            3.721100     3.297963
# 2014-01-13 14:00:00                            3.651154     2.909797
# ...                                                 ...          ...
# 2015-06-29 15:30:00                            2.796333     3.297963
# 2015-06-29 15:45:00                            2.824535     1.939670
# 2015-06-29 16:00:00                            1.622387     1.357711
# 2015-06-29 16:15:00                            1.291134     2.716004
# 2015-06-29 16:30:00                            2.463394     2.521630
#
# [50481 rows x 2 columns]

# %%
predicted_DF_linearReg_CV_sept_week1=predicted_DF_linearReg_split_Gas.loc['2014-09-01':'2014-09-08']
predicted_DF_linearReg_CV_sept_week1.plot()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
MAE_linearReg_CV_Gas = mean_absolute_error(predict_linearReg_CV_Gas,DF_target_Gas)
MSE_linearReg_CV_Gas = mean_squared_error(predict_linearReg_CV_Gas,DF_target_Gas)
R2_linear_CV_Gas=r2_score(predict_linearReg_CV_Gas,DF_target_Gas)
print('MAE : ' + str(MAE_linearReg_CV_Gas))
print('MSE : ' + str(MSE_linearReg_CV_Gas))
print('R2 : ' + str(R2_linear_CV_Gas))
# Out:
# MAE : 0.8514816302521047
# MSE : 1.326725715678431
# R2 : 0.9222797895970728

# %% [markdown]
# ### Cross Validation Method, Random Forrest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
RF_reg_Gas= RandomForestRegressor()

# %%
predict_RF_reg_CV_Gas = cross_val_predict(RF_reg_Gas,DF_features_Gas,DF_target_Gas, cv=10)

# %%
Predicted_DF_RF_reg_CV_Gas = pd.DataFrame(predict_RF_reg_CV_Gas, index= DF_target_Gas.index, columns=["EE_cons_predicted_RF_reg_CV_Gas"])
Predicted_DF_RF_reg_CV_Gas.head(24)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Gas
# Date Time
# 2014-01-13 13:00:00                         4.572204
# 2014-01-13 13:15:00                         4.461678
# 2014-01-13 13:30:00                         3.949577
# 2014-01-13 13:45:00                         3.097950
# 2014-01-13 14:00:00                         3.163932
# 2014-01-13 14:15:00                         2.719694
# 2014-01-13 14:30:00                         1.924388
# 2014-01-13 14:45:00                         2.069843
# 2014-01-13 15:00:00                         2.100861
# 2014-01-13 15:15:00                         2.073696
# 2014-01-13 15:30:00                         1.988345
# 2014-01-13 15:45:00                         1.914646
# 2014-01-13 16:00:00                         2.131892
# 2014-01-13 16:15:00                         1.999990
# 2014-01-13 16:30:00                         2.296784
# 2014-01-13 16:45:00                         2.490751
# 2014-01-13 17:00:00                         3.687626
# 2014-01-13 17:15:00                         4.481075
# 2014-01-13 17:30:00                         5.544117
# 2014-01-13 17:45:00                         6.903917
# 2014-01-13 18:00:00                         5.414154
# 2014-01-13 18:15:00                         5.020353
# 2014-01-13 18:30:00                         5.350144
# 2014-01-13 18:45:00                         5.441325

# %%
Predicted_DF_RF_reg_CV_Gas=Predicted_DF_RF_reg_CV_Gas.join(DF_target_Gas)

# %%
Predicted_DF_RF_reg_CV_Gas.head(20)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Gas  Consumption
# Date Time
# 2014-01-13 13:00:00                         4.572204     4.655675
# 2014-01-13 13:15:00                         4.461678     4.073715
# 2014-01-13 13:30:00                         3.949577     3.297963
# 2014-01-13 13:45:00                         3.097950     3.297963
# 2014-01-13 14:00:00                         3.163932     2.909797
# 2014-01-13 14:15:00                         2.719694     2.134045
# 2014-01-13 14:30:00                         1.924388     1.939670
# 2014-01-13 14:45:00                         2.069843     1.939670
# 2014-01-13 15:00:00                         2.100861     1.939670
# 2014-01-13 15:15:00                         2.073696     1.745878
# 2014-01-13 15:30:00                         1.988345     1.939670
# 2014-01-13 15:45:00                         1.914646     2.327837
# 2014-01-13 16:00:00                         2.131892     2.327837
# 2014-01-13 16:15:00                         1.999990     2.327837
# 2014-01-13 16:30:00                         2.296784     2.716004
# 2014-01-13 16:45:00                         2.490751     3.685548
# 2014-01-13 17:00:00                         3.687626     4.267508
# 2014-01-13 17:15:00                         4.481075     5.431426
# 2014-01-13 17:30:00                         5.544117     6.595345
# 2014-01-13 17:45:00                         6.903917     5.237634

# %%
MAE_RF_reg_CV_Gas= mean_absolute_error(predict_RF_reg_CV_Gas,DF_target_Gas)
MSE_RF_reg_CV_Gas= mean_squared_error(predict_RF_reg_CV_Gas,DF_target_Gas)
R2_RF_reg_CV_Gas = r2_score(predict_RF_reg_CV_Gas,DF_target_Gas)
print("MAE CV:"+str(MAE_RF_reg_CV_Gas))
print("MSE CV:"+ str(MSE_RF_reg_CV_Gas))
print("R2 CV:"+str(R2_RF_reg_CV_Gas))
# Out:
# MAE CV:0.8359554455646389
# MSE CV:1.3190696105329882
# R2 CV:0.9220038115698318

# %% [markdown]
# ### Online learning

# %%
DF_joined_Gas = DF_joined_Gas.sort_index()

# %%
DF_onlineConsumptionPrediction_Gas = pd.DataFrame(index=DF_joined_Gas.index)

firstTimeStampMeasured_Gas=DF_joined_Gas.index[0]
lastTimeStampMeasured_Gas= DF_joined_Gas.index[-1]

DF_onlineConsumptionPrediction_Gas
# Out:
# Empty DataFrame
# Columns: []
# Index: [2014-01
 09:30:00, 2014-01-14 09:45:00, 2014-01-14 10:00:00, 2014-01-14 10:15:00, 2014-01-14 10:30:00, 2014-01-14 10:45:00, 2014-01-14 11:00:00, 2014-01-14 11:15:00, 2014-01-14 11:30:00, 2014-01-14 11:45:00, 2014-01-14 12:00:00, 2014-01-14 12:15:00, 2014-01-14 12:30:00, 2014-01-14 12:45:00, 2014-01-14 13:00:00, 2014-01-14 13:15:00, 2014-01-14 13:30:00, 2014-01-14 13:45:00, ...]
#
# [50471 rows x 0 columns]

# %%
DF_onlineConsumptionPrediction_Gas = DF_onlineConsumptionPrediction_Gas.truncate(before=FirstTimeStampToPredict_Gas)    
DF_onlineConsumptionPrediction_Gas.index
# Out:
# DatetimeIndex(['2014-02-12 13:00:00', '2014-02-12 13:15:00',
#                '2014-02-12 13:30:00', '2014-02-12 13:45:00',
#                '2014-02-12 14:00:00', '2014-02-12 14:15:00',
#                '2014-02-12 14:30:00', '2014-02-12 14:45:00',
#                '2014-02-12 15:00:00', '2014-02-12 15:15:00',
#                ...
#                '2015-06-29 14:15:00', '2015-06-29 14:30:00',
#                '2015-06-29 14:45:00', '2015-06-29 15:00:00',
#                '2015-06-29 15:15:00', '2015-06-29 15:30:00',
#                '2015-06-29 15:45:00', '2015-06-29 16:00:00',
#                '2015-06-29 16:15:00', '2015-06-29 16:30:00'],
#               dtype='datetime64[ns]', name='Date Time', length=47628, freq=None)

# %%
DF_target_Gas
# Out:
# Date Time
# 2014-01-13 13:00:00    4.655675
# 2014-01-13 13:15:00    4.073715
# 2014-01-13 13:30:00    3.297963
# 2014-01-13 13:45:00    3.297963
# 2014-01-13 14:00:00    2.909797
#                          ...
# 2015-06-29 15:30:00    3.297963
# 2015-06-29 15:45:00    1.939670
# 2015-06-29 16:00:00    1.357711
# 2015-06-29 16:15:00    2.716004
# 2015-06-29 16:30:00    2.521630
# Name: Consumption, Length: 50471, dtype: float64

# %%
DF_target_reshaped_Gas=DF_target_Gas.to_frame()
DF_target_reshaped_Gas
# Out:
#                      Consumption
# Date Time
# 2014-01-13 13:00:00     4.655675
# 2014-01-13 13:15:00     4.073715
# 2014-01-13 13:30:00     3.297963
# 2014-01-13 13:45:00     3.297963
# 2014-01-13 14:00:00     2.909797
# ...                          ...
# 2015-06-29 15:30:00     3.297963
# 2015-06-29 15:45:00     1.939670
# 2015-06-29 16:00:00     1.357711
# 2015-06-29 16:15:00     2.716004
# 2015-06-29 16:30:00     2.521630
#
# [50471 rows x 1 columns]

# %%
DF_target2_Gas = DF_joined_Gas.loc[:,["Consumption"]]
DF_target2_Gas
# Out:
#                      Consumption
# Date Time
# 2014-01-13 13:00:00     4.655675
# 2014-01-13 13:15:00     4.073715
# 2014-01-13 13:30:00     3.297963
# 2014-01-13 13:45:00     3.297963
# 2014-01-13 14:00:00     2.909797
# ...                          ...
# 2015-06-29 15:30:00     3.297963
# 2015-06-29 15:45:00     1.939670
# 2015-06-29 16:00:00     1.357711
# 2015-06-29 16:15:00     2.716004
# 2015-06-29 16:30:00     2.521630
#
# [50471 rows x 1 columns]

# %%
DF_joined_Gas.index
# Out:
# DatetimeIndex(['2014-01-13 13:00:00', '2014-01-13 13:15:00',
#                '2014-01-13 13:30:00', '2014-01-13 13:45:00',
#                '2014-01-13 14:00:00', '2014-01-13 14:15:00',
#                '2014-01-13 14:30:00', '2014-01-13 14:45:00',
#                '2014-01-13 15:00:00', '2014-01-13 15:15:00',
#                ...
#                '2015-06-29 14:15:00', '2015-06-29 14:30:00',
#                '2015-06-29 14:45:00', '2015-06-29 15:00:00',
#                '2015-06-29 15:15:00', '2015-06-29 15:30:00',
#                '2015-06-29 15:45:00', '2015-06-29 16:00:00',
#                '2015-06-29 16:15:00', '2015-06-29 16:30:00'],
#               dtype='datetime64[ns]', name='Date Time', length=50471, freq=None)

# %%
timeStampToPredict_Gas = FirstTimeStampToPredict_Gas  #means start one month (period of training) after the first time stamp measured
while(timeStampToPredict_Gas <= lastTimeStampMeasured_Gas): #do it from one month after the first time stamp measured to the last time stamp
  if timeStampToPredict_Gas in DF_joined_Gas.index:
    DF_features_train_Gas = DF_features_Gas.truncate(before=trainingStartTimeStamp_Gas, after=trainingEndTimeStamp_Gas) #from features in one month training period, remove whatever is outside this month
    DF_target_train_Gas = DF_target_Gas.truncate(before=trainingStartTimeStamp_Gas, after=trainingEndTimeStamp_Gas) #from target in one month training period, remove whatever is outside this month
    DF_features_test_Gas = DF_features_Gas.loc[timeStampToPredict_Gas,:].values.reshape(1,-1)    # reshape the values into standard numpy array form
    DF_target_test_Gas = DF_target2_Gas.loc[timeStampToPredict_Gas,"Consumption"]  
    #lets train
    #RF_reg.fit(DF_features_train_Gas,DF_target_train_Gas)
    #linear_reg_Gas.fit(DF_features_train_Gas,DF_target_train_Gas)
    #predicted_consumption = RF_reg.predict(DF_feature_test)
    predicted_consumption_Gas = linear_reg_Gas.predict(DF_features_test_Gas)
    DF_onlineConsumptionPrediction_Gas.loc[timeStampToPredict_Gas,"Predicted"] = predicted_consumption_Gas
    DF_onlineConsumptionPrediction_Gas.loc[timeStampToPredict_Gas,"Real"] = DF_target_test_Gas
  else:
    pass


  timeStampToPredict_Gas = timeStampToPredict_Gas + pd.Timedelta(1,unit="h")  # the indicator is updated by one hour
  #now we have to shift forward the "one month training period" by an hour to make sure we use all the data set once as training.
  trainingStartTimeStamp_Gas = trainingStartTimeStamp_Gas + pd.Timedelta(1,unit="h")
  trainingEndTimeStamp_Gas = trainingEndTimeStamp_Gas + pd.Timedelta(1,unit="h")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-a1687adbdf07> in <module>()
#      20   #now we have to shift forward the "one month training period" by an hour to make sure we use all the data set once as training.
#      21   trainingStartTimeStamp_Gas = trainingStartTimeStamp_Gas + pd.Timedelta(1,unit="h")
# ---> 22   trainingEndTimeStamp_Gas = trainingEndTimeStamp_Gass + pd.Timedelta(1,unit="h")
#
# NameError: name 'trainingEndTimeStamp_Gass' is not defined

# %%
DF_onlineConsumptionPrediction_Gas.dropna(inplace=True)

# %% [markdown]
# #Merging Gas And Electrical Consumption

# %%
DF_joined=pd.merge( DF_main_clean, DF_extra_clean, left_index=True, right_index=True)
DF_joined_Gas_Electrical=pd.merge(DF_joined_Gas,DF_joined,  left_index=True, right_index=True).drop_duplicates()
DF_joined_Gas_Electrical=DF_joined_Gas_Electrical.dropna()
#DF_joined_Gas_Electrical=DF_joined_Gas_Electrical.drop("reduced_cons", axis=1)
DF_joined_Gas_Electrical=DF_joined_Gas_Electrical.drop("reduced_cons_Gas", axis=1)
DF_joined_Gas_Electrical
# Out:
#                      Consumption  temp_set_1_x  ...  precep_y   rad_y
# 2014-01-13 13:00:00     4.655675         61.65  ...       0.0   513.4
# 2014-01-13 13:15:00     4.073715         62.33  ...       0.0   504.0
# 2014-01-13 13:30:00     3.297963         63.37  ...       0.0   491.0
# 2014-01-13 14:00:00     2.909797         64.15  ...       0.0   454.1
# 2014-01-13 14:45:00     1.939670         64.87  ...       0.0   375.6
# ...                          ...           ...  ...       ...     ...
# 2015-06-29 13:00:00     3.103589         66.90  ...       0.0   994.0
# 2015-06-29 13:45:00     2.134045         68.95  ...       0.0  1000.0
# 2015-06-29 15:30:00     3.297963         70.65  ...       0.0   871.0
# 2015-06-29 15:45:00     1.939670         70.39  ...       0.0   840.0
# 2015-06-29 16:15:00     2.716004         70.81  ...       0.0   770.8
#
# [32902 rows x 43 columns]

# %% [markdown]
# ## Defining feature and target

# %%
# we consider gas consumption as target and others as features
DF_joined_Gas_Electrical=DF_joined_Gas_Electrical.dropna()
DF_target_Gas_Electrical= DF_joined_Gas_Electrical["Consumption"] # I am actually making a series , we could also use double brackets
DF_features_Gas_Electrical= DF_joined_Gas_Electrical.drop("Consumption", axis=1) # I am actually m.dropaking a series , we could also use double brackets
#note that the value of reduced_cons is actually directly referring to the consumption with a different form. as it can make the learning biased, it should be removed from the features.
#DF_features_Gas_Electrical= DF_features_Gas_Electrical.drop("reduced_cons", axis=1)
DF_target_Gas_Electrical
# Out:
# 2014-01-13 13:00:00    4.655675
# 2014-01-13 13:15:00    4.073715
# 2014-01-13 13:30:00    3.297963
# 2014-01-13 14:00:00    2.909797
# 2014-01-13 14:45:00    1.939670
#                          ...
# 2015-06-29 13:00:00    3.103589
# 2015-06-29 13:45:00    2.134045
# 2015-06-29 15:30:00    3.297963
# 2015-06-29 15:45:00    1.939670
# 2015-06-29 16:15:00    2.716004
# Name: Consumption, Length: 32902, dtype: float64

# %%
# we consider electrical consumption target and others as features
DF_joined_Electrical_Gas=DF_joined_Gas_Electrical.dropna()
DF_target_Electrical_Gas= DF_joined_Electrical_Gas["consumption"] # I am actually making a series , we could also use double brackets
DF_features_Electrical_Gas= DF_joined_Electrical_Gas.drop("consumption", axis=1) # I am actually m.dropaking a series , we could also use double brackets
#note that the value of reduced_cons is actually directly referring to the consumption with a different form. as it can make the learning biased, it should be removed from the features.
#DF_features_Electrical_Gas= DF_features_Electrical_Gas.drop("reduced_cons", axis=1)
DF_target_Electrical_Gas
# Out:
# 2014-01-13 13:00:00    34.21000
# 2014-01-13 13:15:00    34.94500
# 2014-01-13 13:30:00    32.44750
# 2014-01-13 14:00:00    33.77500
# 2014-01-13 14:45:00    34.92000
#                          ...
# 2015-06-29 13:00:00    46.01601
# 2015-06-29 13:45:00    47.99200
# 2015-06-29 15:30:00    49.99200
# 2015-06-29 15:45:00    49.96800
# 2015-06-29 16:15:00    51.03200
# Name: consumption, Length: 32902, dtype: float64

# %%
DF_features_Gas_Electrical=DF_features_Gas_Electrical.drop("reduced_cons_Gas", axis=1)
DF_features_Gas_Electrical.columns
# Out:
# Index(['temp_set_1_x', 'temp_set_2_x', 'RH_x', 'wind_speed_x', 'precep_x',
#        'rad_x', 'hour', 'sin(hour)', 'cos(hour)', 'month', 'dayOfWeek',
#        'weekOfYear', 'weekendLabel', 'WorkingHourLabel', 'temp_avg',
#        'temp_avg -1h', 'temp_avg -2h', 'temp_avg -3h', 'Consumption -1h',
#        'Consumption -25h', 'Consumption -49h', 'Consumption -73h',
#        'Consumption -97h', 'Consumption -121h', 'Consumption -145h',
#        'Consumption -169h', 'Consumption -193h', 'Consumption -217h',
#        'rad -3h', 'rad -4h', 'rad -5h', 'rad -6h', 'scaled_rad',
#        'temp_avg_degc', 'temp_avg_comfort', 'consumption', 'temp_set_1_y',
#        'temp_set_2_y', 'RH_y', 'wind_speed_y', 'precep_y', 'rad_y'],
#       dtype='object')

# %% [markdown]
# ###Applying learning model to Gas consumption
# ####Cross validation method Random Forrest regression

# %%
from sklearn.model_selection import cross_val_predict
predict_linearReg_CV_Gas_Electrical = cross_val_predict(linear_reg_Gas,DF_features_Gas_Electrical,DF_target_Gas_Electrical)

# %%
predict_RF_reg_CV_Gas_Electrical = cross_val_predict(RF_reg_Gas,DF_features_Gas_Electrical,DF_target_Gas_Electrical, cv=10)

# %%
Predicted_DF_RF_reg_CV_Gas_Electrical = pd.DataFrame(predict_RF_reg_CV_Gas_Electrical, index= DF_target_Gas_Electrical.index, columns=["EE_cons_predicted_RF_reg_CV_Gas_Electrical"])
Predicted_DF_RF_reg_CV_Gas_Electrical.head(24)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Gas_Electrical
# 2014-01-13 13:00:00                                    4.517925
# 2014-01-13 13:15:00                                    4.395725
# 2014-01-13 13:30:00                                    3.741981
# 2014-01-13 14:00:00                                    3.072774
# 2014-01-13 14:45:00                                    2.032970
# 2014-01-13 15:00:00                                    2.205597
# 2014-01-13 15:15:00                                    2.120264
# 2014-01-13 15:30:00                                    1.811843
# 2014-01-13 15:45:00                                    1.893323
# 2014-01-13 16:00:00                                    2.380219
# 2014-01-13 16:15:00                                    2.483028
# 2014-01-13 16:30:00                                    2.541213
# 2014-01-13 16:45:00                                    2.870986
# 2014-01-13 17:00:00                                    3.966990
# 2014-01-13 17:45:00                                    6.729353
# 2014-01-13 18:00:00                                    5.330718
# 2014-01-13 18:15:00                                    4.967965
# 2014-01-13 18:30:00                                    5.342357
# 2014-01-13 18:45:00                                    5.522800
# 2014-01-13 19:00:00                                    5.319091
# 2014-01-13 19:15:00                                    5.501407
# 2014-01-13 19:30:00                                    6.777841
# 2014-01-13 19:45:00                                    6.865159
# 2014-01-13 20:00:00                                    7.063013

# %%
Predicted_DF_RF_reg_CV_Gas_Electrical=Predicted_DF_RF_reg_CV_Gas_Electrical.join( DF_target_Gas_Electrical)

# %%
Predicted_DF_RF_reg_CV_Gas_Electrical.head(20)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Gas_Electrical  Consumption
# 2014-01-13 13:00:00                                    4.517925     4.655675
# 2014-01-13 13:15:00                                    4.395725     4.073715
# 2014-01-13 13:30:00                                    3.741981     3.297963
# 2014-01-13 14:00:00                                    3.072774     2.909797
# 2014-01-13 14:45:00                                    2.032970     1.939670
# 2014-01-13 15:00:00                                    2.205597     1.939670
# 2014-01-13 15:15:00                                    2.120264     1.745878
# 2014-01-13 15:30:00                                    1.811843     1.939670
# 2014-01-13 15:45:00                                    1.893323     2.327837
# 2014-01-13 16:00:00                                    2.380219     2.327837
# 2014-01-13 16:15:00                                    2.483028     2.327837
# 2014-01-13 16:30:00                                    2.541213     2.716004
# 2014-01-13 16:45:00                                    2.870986     3.685548
# 2014-01-13 17:00:00                                    3.966990     4.267508
# 2014-01-13 17:45:00                                    6.729353     5.237634
# 2014-01-13 18:00:00                                    5.330718     4.655675
# 2014-01-13 18:15:00                                    4.967965     5.237634
# 2014-01-13 18:30:00                                    5.342357     5.431426
# 2014-01-13 18:45:00                                    5.522800     4.849467
# 2014-01-13 19:00:00                                    5.319091     5.043841

# %%
MAE_RF_reg_CV_Gas_Electrical= mean_absolute_error(predict_RF_reg_CV_Gas_Electrical, DF_target_Gas_Electrical)
MSE_RF_reg_CV_Gas_Electrical= mean_squared_error(predict_RF_reg_CV_Gas_Electrical, DF_target_Gas_Electrical)
R2_RF_reg_CV_Gas_Electrical = r2_score(predict_RF_reg_CV_Gas_Electrical, DF_target_Gas_Electrical)
print("MAE CV:"+str(MAE_RF_reg_CV_Gas_Electrical))
print("MSE CV:"+ str(MSE_RF_reg_CV_Gas_Electrical))
print("R2 CV:"+str(R2_RF_reg_CV_Gas_Electrical))
# Out:
# MAE CV:0.7744931249824721
# MSE CV:1.1388251649656895
# R2 CV:0.9310952770587101

# %% [markdown]
# ###Applying learning model to Electrical consumption
# ####Cross validation method Random Forrest regression

# %%
DF_joined_Electrical_Gas.corr()
# Out:
#                    Consumption  temp_set_1_x  ...  precep_y     rad_y
# Consumption           1.000000     -0.795693  ...  0.088819 -0.456300
# temp_set_1_x         -0.795693      1.000000  ... -0.076535  0.481904
# temp_set_2_x         -0.777236      0.974050  ... -0.079128  0.400763
# RH_x                  0.298322     -0.567179  ...  0.096829 -0.303155
# wind_speed_x          0.029443     -0.067898  ...  0.134290  0.095606
# precep_x              0.088819     -0.076535  ...  1.000000 -0.069018
# rad_x                -0.456300      0.481904  ... -0.069018  1.000000
# hour                 -0.281836      0.229305  ... -0.016034  0.142190
# sin(hour)             0.392135     -0.324101  ...  0.025238 -0.183695
# cos(hour)             0.253815     -0.314639  ... -0.010791 -0.739283
# month                -0.142073      0.176728  ...  0.055846 -0.083980
# dayOfWeek            -0.022020     -0.024577  ...  0.004213  0.001120
# weekOfYear           -0.214790      0.223884  ...  0.057464 -0.075474
# weekendLabel         -0.017775     -0.024296  ... -0.011850  0.002781
# WorkingHourLabel     -0.374111      0.385077  ...  0.000075  0.769326
# temp_avg             -0.791908      0.993900  ... -0.078299  0.445522
# temp_avg -1h         -0.791506      0.984411  ... -0.074896  0.423209
# temp_avg -2h         -0.789087      0.976658  ... -0.072386  0.399923
# temp_avg -3h         -0.783944      0.967474  ... -0.070654  0.375283
# Consumption -1h       0.962839     -0.791719  ...  0.086506 -0.435909
# Consumption -25h      0.458262     -0.411642  ...  0.058781  0.251886
# Consumption -49h      0.295451     -0.293901  ...  0.042293  0.098416
# Consumption -73h      0.449481     -0.457061  ...  0.035901 -0.271888
# Consumption -97h      0.772003     -0.655473  ...  0.067192 -0.391079
# Consumption -121h     0.362208     -0.287519  ...  0.072459  0.268053
# Consumption -145h     0.213951     -0.175613  ...  0.056974  0.103882
# Consumption -169h     0.365814     -0.351986  ...  0.056332 -0.269667
# Consumption -193h     0.671460     -0.557876  ...  0.067604 -0.382322
# Consumption -217h     0.300946     -0.212460  ...  0.062277  0.261643
# rad -3h              -0.496877      0.529403  ... -0.067106  0.952663
# rad -4h              -0.502909      0.538764  ... -0.066360  0.928297
# rad -5h              -0.506883      0.545600  ... -0.065796  0.899433
# rad -6h              -0.508646      0.549235  ... -0.065633  0.866100
# scaled_rad           -0.456300      0.481904  ... -0.069018  1.000000
# reduced_cons_Gas      1.000000     -0.795693  ...  0.088819 -0.456300
# temp_avg_degc        -0.791908      0.993900  ... -0.078299  0.445522
# temp_avg_comfort     -0.791908      0.993900  ... -0.078299  0.445522
# consumption          -0.010405      0.026193  ... -0.000736  0.013399
# temp_set_1_y         -0.795693      0.999992  ... -0.076535  0.481904
# temp_set_2_y         -0.777236      0.974041  ... -0.079128  0.400763
# RH_y                  0.298322     -0.567163  ...  0.096829 -0.303155
# wind_speed_y          0.029443     -0.067885  ...  0.134290  0.095606
# precep_y              0.088819     -0.076535  ...  1.000000 -0.069018
# rad_y                -0.456300      0.481904  ... -0.069018  1.000000
#
# [44 rows x 44 columns]

# %%
DF_features_Electrical_Gas
DF_target_Electrical_Gas
# Out:
# 2014-01-13 13:00:00    34.21000
# 2014-01-13 13:15:00    34.94500
# 2014-01-13 13:30:00    32.44750
# 2014-01-13 14:00:00    33.77500
# 2014-01-13 14:45:00    34.92000
#                          ...
# 2015-06-29 13:00:00    46.01601
# 2015-06-29 13:45:00    47.99200
# 2015-06-29 15:30:00    49.99200
# 2015-06-29 15:45:00    49.96800
# 2015-06-29 16:15:00    51.03200
# Name: consumption, Length: 32902, dtype: float64

# %%
from sklearn.model_selection import cross_val_predict
#predict_RF_reg_CV_Electrical_Gas = cross_val_predict(RF_reg,DF_features_Electrical_Gas,DF_target_Electrical_Gas)

# %%
predict_RF_reg_CV_Electrical_Gas = cross_val_predict(RF_reg,DF_features_Electrical_Gas,DF_target_Electrical_Gas, cv=10)

# %%
Predicted_DF_RF_reg_CV_Electrical_Gas = pd.DataFrame(predict_RF_reg_CV_Electrical_Gas, index= DF_target_Electrical_Gas.index, columns=["EE_cons_predicted_RF_reg_CV_Electrical_Gas"])
Predicted_DF_RF_reg_CV_Electrical_Gas.head(24)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Electrical_Gas
# 2014-01-13 13:00:00                                   53.561460
# 2014-01-13 13:15:00                                   60.992728
# 2014-01-13 13:30:00                                   44.187073
# 2014-01-13 14:00:00                                   37.466269
# 2014-01-13 14:45:00                                   38.745258
# 2014-01-13 15:00:00                                   36.042648
# 2014-01-13 15:15:00                                   36.199185
# 2014-01-13 15:30:00                                   36.800745
# 2014-01-13 15:45:00                                   36.585715
# 2014-01-13 16:00:00                                   35.570830
# 2014-01-13 16:15:00                                   34.850454
# 2014-01-13 16:30:00                                   35.660276
# 2014-01-13 16:45:00                                   37.554194
# 2014-01-13 17:00:00                                   39.051267
# 2014-01-13 17:45:00                                   36.411969
# 2014-01-13 18:00:00                                   47.547610
# 2014-01-13 18:15:00                                   34.678441
# 2014-01-13 18:30:00                                   34.710898
# 2014-01-13 18:45:00                                   31.382886
# 2014-01-13 19:00:00                                   31.365931
# 2014-01-13 19:15:00                                   31.043556
# 2014-01-13 19:30:00                                   30.926392
# 2014-01-13 19:45:00                                   38.869474
# 2014-01-13 20:00:00                                   29.920207

# %%
Predicted_DF_RF_reg_CV_Electrical_Gas=Predicted_DF_RF_reg_CV_Electrical_Gas.join(DF_target_Electrical_Gas)

# %%
Predicted_DF_RF_reg_CV_Electrical_Gas.head(20)
# Out:
#                      EE_cons_predicted_RF_reg_CV_Electrical_Gas  consumption
# 2014-01-13 13:00:00                                   53.561460      34.2100
# 2014-01-13 13:15:00                                   60.992728      34.9450
# 2014-01-13 13:30:00                                   44.187073      32.4475
# 2014-01-13 14:00:00                                   37.466269      33.7750
# 2014-01-13 14:45:00                                   38.745258      34.9200
# 2014-01-13 15:00:00                                   36.042648      34.8800
# 2014-01-13 15:15:00                                   36.199185      35.0800
# 2014-01-13 15:30:00                                   36.800745      34.9600
# 2014-01-13 15:45:00                                   36.585715      35.5950
# 2014-01-13 16:00:00                                   35.570830      33.7825
# 2014-01-13 16:15:00                                   34.850454      35.1125
# 2014-01-13 16:30:00                                   35.660276      35.9275
# 2014-01-13 16:45:00                                   37.554194      36.3375
# 2014-01-13 17:00:00                                   39.051267      32.7750
# 2014-01-13 17:45:00                                   36.411969      33.7075
# 2014-01-13 18:00:00                                   47.547610      33.3600
# 2014-01-13 18:15:00                                   34.678441      31.0875
# 2014-01-13 18:30:00                                   34.710898      31.4450
# 2014-01-13 18:45:00                                   31.382886      28.7625
# 2014-01-13 19:00:00                                   31.365931      30.2900

# %%
MAE_RF_reg_CV_Electrical_Gas= mean_absolute_error(predict_RF_reg_CV_Electrical_Gas,DF_target_Electrical_Gas)
MSE_RF_reg_CV_Electrical_Gas= mean_squared_error(predict_RF_reg_CV_Electrical_Gas,DF_target_Electrical_Gas)
R2_RF_reg_CV_Electrical_Gas = r2_score(predict_RF_reg_CV_Electrical_Gas,DF_target_Electrical_Gas)
print("MAE CV:"+str(MAE_RF_reg_CV_Electrical_Gas))
print("MSE CV:"+ str(MSE_RF_reg_CV_Electrical_Gas))
print("R2 CV:"+str(R2_RF_reg_CV_Electrical_Gas))
# Out:
# MAE CV:45.14839759488617
# MSE CV:1531913.047334897
# R2 CV:-415.30092266984764
